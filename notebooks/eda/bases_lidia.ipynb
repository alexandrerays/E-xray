# %%
import pandas as pd

# %%
ideb_escola_2017 = pd.read_csv('../../data/bases_lidia/anos_iniciais/ideb_escola_2017_ai.csv')

# %%
ideb_escola_2017.head().T
# Out:
#                                                                            0  \
# Unnamed: 0                                                                 0
# Unnamed: 0.1                                                               0
# ano_censo                                                               2017
# cod_escola_inep                                                     11002441
# regiao                                                                 Norte
# municipio                                                        Porto Velho
# tp_dependencia                                                             2
# tp_rede_publica                                                          NaN
# rede_publica_desc                                                    privada
# in_somente_matriculas_ac_ou_aee                                          NaN
# tp_rede_x                                                           Estadual
# ...
