# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer

# %%
def calculate_pearson(df):
    correlations = {}
    numerical_features = df.select_dtypes(exclude = ["object"]).columns
    numerical_features = numerical_features.drop("cod_municipio")
    for i in numerical_features:
        corr = stats.pearsonr(df[i], df['ideb'])[0]
        correlations[i] = corr
    df_corr = pd.DataFrame(list(correlations.items()), columns=['feature', 'correlation_with_ideb'])        
    df_corr = df_corr.dropna()
    
    return df_corr

# %%
def calculate_categorical_correlation(df):
    categorical_features = df.select_dtypes(include = ["object"]).columns
    return categorical_features

# %% [markdown]
# # Puxa dados do CSV de cada integrante do grupo

# %% [markdown]
# ### Dados Alexandre

# %%
path = '../../data/bcggammachallenge'

# %%
#Dados iniciais
alexandre_inicio_2015 = pd.read_csv(path + '/bases_ale/anos iniciais/ideb_municipios_2015_ai.csv')
alexandre_inicio_2017 = pd.read_csv(path + 'bases_ale/anos iniciais/ideb_municipios_2017_ai.csv')

# Dados finais
alexandre_final_2015 = pd.read_csv(path + 'base_ale/anos finais/ideb_municipios_2015_af.csv')
alexandre_final_2017 = pd.read_csv(path + 'base_ale/anos finais/ideb_municipios_2017_af.csv')

# %% [markdown]
# ### Dados Lidia

# %%
#Dados iniciais
lidia_inicio_2007 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2007_ai.csv')
lidia_inicio_2009 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2009_ai.csv')
lidia_inicio_2011 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2011_ai.csv')
lidia_inicio_2013 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2013_ai.csv')
lidia_inicio_2015 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2015_ai.csv')
lidia_inicio_2017 = pd.read_csv(path + 'bases_lidia/Anos iniciais/ideb_escola_2017_ai.csv')

# Dados finais
lidia_final_2007 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2007_af.csv')
lidia_final_2009 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2009_af.csv')
lidia_final_2011 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2011_af.csv')
lidia_final_2013 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2013_af.csv')
lidia_final_2015 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2015_af.csv')
lidia_final_2017 = pd.read_csv(path + 'bases_lidia/Anos finais/ideb_escola_2017_af.csv')
# Out:
# C:\Users\William\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (48,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\William\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (48,50,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\William\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (48,50,52,170) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\William\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (47,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\William\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (47,49,51,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Dados William

# %%
#Dados iniciais
william_inicio_2005 = pd.read_csv(path + 'base_william/ano inicial/dados2005_inic.csv')
william_inicio_2007 = pd.read_csv(path + 'base_william/ano inicial/dados2007_inic.csv')
william_inicio_2009 = pd.read_csv(path + 'base_william/ano inicial/dados2009_inic.csv')
william_inicio_2011 = pd.read_csv(path + 'base_william/ano inicial/dados2011_inic.csv')
william_inicio_2013 = pd.read_csv(path + 'base_william/ano inicial/dados2013_inic.csv')
william_inicio_2015 = pd.read_csv(path + 'base_william/ano inicial/dados2015_inic.csv')
william_inicio_2017 = pd.read_csv(path + 'base_william/ano inicial/dados2017_inic.csv')


# Dados finais
william_final_2005 = pd.read_csv(path + 'base_william/ano final/dados2005_fim.csv')
william_final_2007 = pd.read_csv(path + 'base_william/ano final/dados2007_fim.csv')
william_final_2009 = pd.read_csv(path + 'base_william/ano final/dados2009_fim.csv')
william_final_2011 = pd.read_csv(path + 'base_william/ano final/dados2011_fim.csv')
william_final_2013 = pd.read_csv(path + 'base_william/ano final/dados2013_fim.csv')
william_final_2015 = pd.read_csv(path + 'base_william/ano final/dados2015_fim.csv')
william_final_2017 = pd.read_csv(path + 'base_william/ano final/dados2017_fim.csv')

# %% [markdown]
# # Retirar dados NaN

# %% [markdown]
# ### Lidia

# %%
print(lidia_inicio_2007.shape)
print(lidia_inicio_2007.count()-lidia_inicio_2007.shape[0])

print(lidia_inicio_2009.shape)
print(lidia_inicio_2009.count()-lidia_inicio_2009.shape[0])

print(lidia_inicio_2011.shape)
print(lidia_inicio_2011.count()-lidia_inicio_2011.shape[0])

print(lidia_inicio_2013.shape)
print(lidia_inicio_2013.count()-lidia_inicio_2013.shape[0])

print(lidia_inicio_2015.shape)
print(lidia_inicio_2015.count()-lidia_inicio_2015.shape[0])

print(lidia_inicio_2017.shape)
print(lidia_inicio_2017.count()-lidia_inicio_2017.shape[0])

print(lidia_final_2007.shape)
print(lidia_final_2007.count()-lidia_final_2007.shape[0])

print(lidia_final_2009.shape)
print(lidia_final_2009.count()-lidia_final_2009.shape[0])

print(lidia_final_2011.shape)
print(lidia_final_2011.count()-lidia_final_2011.shape[0])

print(lidia_final_2013.shape)
print(lidia_final_2013.count()-lidia_final_2013.shape[0])

print(lidia_final_2015.shape)
print(lidia_final_2015.count()-lidia_final_2015.shape[0])

print(lidia_final_2017.shape)
print(lidia_final_2017.count()-lidia_final_2017.shape[0])
# Out:
# (41759, 204)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                               -80
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee               -80
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                                -80
# num_estudantes                                -80
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil                -80
# num_estudantes_ensino_fund_anos_iniciais      -80
# num_estudantes_ensino_fund_anos_finais        -80
# num_estudantes_ensino_medio_propedeutico      -80
# num_estudantes_fund_1_ano                     -80
# num_estudantes_fund_2_ano                     -80
# num_estudantes_fund_3_ano                     -80
#                                             ...
# ideb_2015_af_media_mat                     -13089
# ideb_2015_af_proficiencia                  -13089
# ideb_2015_af_fluxo                         -10128
# ideb_2015_anos_finais                      -13098
# tp_aee                                          0
# tp_aee_desc                                -41759
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -41759
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                   -80
# tp_localizacao_diferenciada_desc              -80
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                          -80
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -41759
# co_lingua_indigena                         -41648
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -41759
# num_estudantes_ensino_integral             -41759
# tp_integral                                -41759
# cod_ibge_uf                                     0
# ano                                        -13254
# ideb                                       -13254
# tp_rede                                    -13254
# uf                                         -13254
# Length: 204, dtype: int64
# (42369, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -217
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -217
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -217
# num_estudantes                               -217
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -217
# num_estudantes_ensino_fund_anos_iniciais     -217
# num_estudantes_ensino_fund_anos_finais       -217
# num_estudantes_ensino_medio_propedeutico     -217
# num_estudantes_fund_1_ano                    -217
# num_estudantes_fund_2_ano                    -217
# num_estudantes_fund_3_ano                    -217
#                                             ...
# num_professores_em_regencia                  -222
# num_professores_em_regencia_fund_ai          -222
# num_professores_em_regencia_fund_af          -222
# num_professores_em_regencia_ens_medio        -222
# tp_aee                                          0
# tp_aee_desc                                -38716
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -33855
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -217
# tp_localizacao_diferenciada_desc             -217
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -217
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42369
# co_lingua_indigena                         -42274
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -42369
# num_estudantes_ensino_integral             -42369
# tp_integral                                -42369
# cod_ibge_uf                                     0
# ano                                        -13459
# ideb                                       -13459
# tp_rede                                    -13459
# uf                                         -13459
# Length: 184, dtype: int64
# (42784, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13649
# ideb                                       -13649
# tp_rede                                    -13649
# uf                                         -13649
# Length: 184, dtype: int64
# (43163, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -625
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -625
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -625
# num_estudantes                               -625
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -625
# num_estudantes_ensino_fund_anos_iniciais     -625
# num_estudantes_ensino_fund_anos_finais       -625
# num_estudantes_ensino_medio_propedeutico     -625
# num_estudantes_fund_1_ano                    -625
# num_estudantes_fund_2_ano                    -625
# num_estudantes_fund_3_ano                    -625
#                                             ...
# num_professores_em_regencia                  -625
# num_professores_em_regencia_fund_ai          -625
# num_professores_em_regencia_fund_af          -625
# num_professores_em_regencia_ens_medio        -625
# tp_aee                                          0
# tp_aee_desc                                -31844
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -20589
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -625
# tp_localizacao_diferenciada_desc             -625
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -625
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43163
# co_lingua_indigena                         -43060
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -22731
# num_estudantes_ensino_integral             -22731
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13805
# ideb                                       -13805
# tp_rede                                    -13805
# uf                                         -13805
# Length: 184, dtype: int64
# (43378, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -792
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -792
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -792
# num_estudantes                               -792
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -792
# num_estudantes_ensino_fund_anos_iniciais     -792
# num_estudantes_ensino_fund_anos_finais       -792
# num_estudantes_ensino_medio_propedeutico     -792
# num_estudantes_fund_1_ano                    -792
# num_estudantes_fund_2_ano                    -792
# num_estudantes_fund_3_ano                    -792
#                                             ...
# num_professores_em_regencia                  -792
# num_professores_em_regencia_fund_ai          -792
# num_professores_em_regencia_fund_af          -792
# num_professores_em_regencia_ens_medio        -792
# tp_aee                                          0
# tp_aee_desc                                -29093
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -18744
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -792
# tp_localizacao_diferenciada_desc             -792
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -792
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43189
# co_lingua_indigena                         -43270
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -18982
# num_estudantes_ensino_integral             -18982
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -13923
# ideb                                       -13923
# tp_rede                                    -13923
# uf                                         -13923
# Length: 184, dtype: int64
# (43586, 184)
# Unnamed: 0                                      0
# Unnamed: 0.1                                    0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                             -1040
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee             -1040
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                              -1040
# num_estudantes                              -1040
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil              -1040
# num_estudantes_ensino_fund_anos_iniciais    -1040
# num_estudantes_ensino_fund_anos_finais      -1040
# num_estudantes_ensino_medio_propedeutico    -1040
# num_estudantes_fund_1_ano                   -1040
# num_estudantes_fund_2_ano                   -1040
# num_estudantes_fund_3_ano                   -1040
#                                             ...
# num_professores_em_regencia                 -1040
# num_professores_em_regencia_fund_ai         -1040
# num_professores_em_regencia_fund_af         -1040
# num_professores_em_regencia_ens_medio       -1040
# tp_aee                                          0
# tp_aee_desc                                -27346
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -22067
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                 -1040
# tp_localizacao_diferenciada_desc            -1040
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                        -1040
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43404
# co_lingua_indigena                         -43461
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -23009
# num_estudantes_ensino_integral             -23009
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                        -14065
# ideb                                       -14065
# tp_rede                                    -14065
# uf                                         -14065
# Length: 184, dtype: int64
# (42784, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
# num_estudantes_fund_4_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (42369, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -217
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -217
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -217
# num_estudantes                               -217
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -217
# num_estudantes_ensino_fund_anos_iniciais     -217
# num_estudantes_ensino_fund_anos_finais       -217
# num_estudantes_ensino_medio_propedeutico     -217
# num_estudantes_fund_1_ano                    -217
# num_estudantes_fund_2_ano                    -217
# num_estudantes_fund_3_ano                    -217
# num_estudantes_fund_4_ano                    -217
#                                             ...
# num_professores_em_regencia                  -222
# num_professores_em_regencia_fund_ai          -222
# num_professores_em_regencia_fund_af          -222
# num_professores_em_regencia_ens_medio        -222
# tp_aee                                          0
# tp_aee_desc                                -38716
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -33855
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -217
# tp_localizacao_diferenciada_desc             -217
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -217
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42369
# co_lingua_indigena                         -42274
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -42369
# num_estudantes_ensino_integral             -42369
# tp_integral                                -42369
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (42784, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -359
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -359
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -359
# num_estudantes                               -359
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -359
# num_estudantes_ensino_fund_anos_iniciais     -359
# num_estudantes_ensino_fund_anos_finais       -359
# num_estudantes_ensino_medio_propedeutico     -359
# num_estudantes_fund_1_ano                    -359
# num_estudantes_fund_2_ano                    -359
# num_estudantes_fund_3_ano                    -359
# num_estudantes_fund_4_ano                    -359
#                                             ...
# num_professores_em_regencia                  -359
# num_professores_em_regencia_fund_ai          -359
# num_professores_em_regencia_fund_af          -359
# num_professores_em_regencia_ens_medio        -359
# tp_aee                                          0
# tp_aee_desc                                -34894
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -28723
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -359
# tp_localizacao_diferenciada_desc             -359
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -359
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -42784
# co_lingua_indigena                         -42682
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -27925
# num_estudantes_ensino_integral             -27925
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43163, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -625
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -625
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -625
# num_estudantes                               -625
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -625
# num_estudantes_ensino_fund_anos_iniciais     -625
# num_estudantes_ensino_fund_anos_finais       -625
# num_estudantes_ensino_medio_propedeutico     -625
# num_estudantes_fund_1_ano                    -625
# num_estudantes_fund_2_ano                    -625
# num_estudantes_fund_3_ano                    -625
# num_estudantes_fund_4_ano                    -625
#                                             ...
# num_professores_em_regencia                  -625
# num_professores_em_regencia_fund_ai          -625
# num_professores_em_regencia_fund_af          -625
# num_professores_em_regencia_ens_medio        -625
# tp_aee                                          0
# tp_aee_desc                                -31844
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -20589
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -625
# tp_localizacao_diferenciada_desc             -625
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -625
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43163
# co_lingua_indigena                         -43060
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -22731
# num_estudantes_ensino_integral             -22731
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43378, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                              -792
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee              -792
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                               -792
# num_estudantes                               -792
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil               -792
# num_estudantes_ensino_fund_anos_iniciais     -792
# num_estudantes_ensino_fund_anos_finais       -792
# num_estudantes_ensino_medio_propedeutico     -792
# num_estudantes_fund_1_ano                    -792
# num_estudantes_fund_2_ano                    -792
# num_estudantes_fund_3_ano                    -792
# num_estudantes_fund_4_ano                    -792
#                                             ...
# num_professores_em_regencia                  -792
# num_professores_em_regencia_fund_ai          -792
# num_professores_em_regencia_fund_af          -792
# num_professores_em_regencia_ens_medio        -792
# tp_aee                                          0
# tp_aee_desc                                -29093
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -18744
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                  -792
# tp_localizacao_diferenciada_desc             -792
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                         -792
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43189
# co_lingua_indigena                         -43270
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -18982
# num_estudantes_ensino_integral             -18982
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64
# (43586, 183)
# Unnamed: 0                                      0
# ano_censo                                       0
# cod_escola_inep                                 0
# regiao                                          0
# municipio                                       0
# tp_dependencia                                  0
# tp_rede_publica                             -1040
# rede_publica_desc                               0
# in_somente_matriculas_ac_ou_aee             -1040
# tp_rede_x                                       0
# tp_rede_nome                                    0
# tp_rede_cod                                     0
# nome_escola                                     0
# num_matriculas                              -1040
# num_estudantes                              -1040
# in_comum_creche                                 0
# in_comum_pre                                    0
# in_comum_fund_ai                                0
# in_comum_fund_af                                0
# in_comum_medio_medio                            0
# in_comum_medio_integrado                        0
# in_comum_medio_normal                           0
# num_estudantes_ensino_infantil              -1040
# num_estudantes_ensino_fund_anos_iniciais    -1040
# num_estudantes_ensino_fund_anos_finais      -1040
# num_estudantes_ensino_medio_propedeutico    -1040
# num_estudantes_fund_1_ano                   -1040
# num_estudantes_fund_2_ano                   -1040
# num_estudantes_fund_3_ano                   -1040
# num_estudantes_fund_4_ano                   -1040
#                                             ...
# num_professores_em_regencia                 -1040
# num_professores_em_regencia_fund_ai         -1040
# num_professores_em_regencia_fund_af         -1040
# num_professores_em_regencia_ens_medio       -1040
# tp_aee                                          0
# tp_aee_desc                                -27346
# tp_atividade_complementar                       0
# tp_atividade_complementar_desc             -22067
# in_fundamental_ciclos                           0
# tp_localizacao_diferenciada                 -1040
# tp_localizacao_diferenciada_desc            -1040
# in_material_esp_quilombola                      0
# in_material_esp_indigena                        0
# in_material_esp_nao_utiliza                     0
# in_educacao_indigena                        -1040
# tp_indigena_lingua                              0
# tp_indigena_lingua_desc                    -43404
# co_lingua_indigena                         -43461
# in_brasil_alfabetizado                          0
# in_final_semana                                 0
# in_formacao_alternancia                         0
# cod_municipio                                   0
# num_matriculas_ensino_integral             -23009
# num_estudantes_ensino_integral             -23009
# tp_integral                                     0
# cod_ibge_uf                                     0
# ano                                             0
# ideb                                            0
# tp_rede_y                                       0
# uf                                              0
# Length: 183, dtype: int64

# %%
print('antes', lidia_inicio_2007.shape)
lidia_inicio_2007 = lidia_inicio_2007.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2007.shape)
lidia_inicio_2007 = lidia_inicio_2007.dropna()
print('dados limpo',lidia_inicio_2007.shape)

print('antes',lidia_inicio_2009.shape)
lidia_inicio_2009 = lidia_inicio_2009.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2009.shape)
lidia_inicio_2009 = lidia_inicio_2009.dropna()
print('dados limpo',lidia_inicio_2009.shape)

print('antes',lidia_inicio_2011.shape)
lidia_inicio_2011 = lidia_inicio_2011.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2011.shape)
lidia_inicio_2011 = lidia_inicio_2011.dropna()
print('dados limpo',lidia_inicio_2011.shape)

print('antes',lidia_inicio_2013.shape)
lidia_inicio_2013 = lidia_inicio_2013.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2013.shape)
lidia_inicio_2013 = lidia_inicio_2013.dropna()
print('dados limpo',lidia_inicio_2013.shape)

print('antes',lidia_inicio_2015.shape)
lidia_inicio_2015 = lidia_inicio_2015.dropna(axis='columns',thresh=15000)
print(lidia_inicio_2015.shape)
lidia_inicio_2015 = lidia_inicio_2015.dropna()
print('dados limpo',lidia_inicio_2015.shape)

print('antes',lidia_inicio_2017.shape)
lidia_inicio_2017 = lidia_inicio_2017.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_inicio_2017.shape)
lidia_inicio_2017 = lidia_inicio_2017.dropna()
print('dados limpo',lidia_inicio_2017.shape)

print('antes', lidia_final_2007.shape)
lidia_final_2007 = lidia_final_2007.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2007.shape)
lidia_final_2007 = lidia_final_2007.dropna()
print('dados limpo',lidia_final_2007.shape)

print('antes',lidia_final_2009.shape)
lidia_final_2009 = lidia_final_2009.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2009.shape)
lidia_final_2009 = lidia_final_2009.dropna()
print('dados limpo',lidia_final_2009.shape)

print('antes',lidia_final_2011.shape)
lidia_final_2011 = lidia_final_2011.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2011.shape)
lidia_final_2011 = lidia_final_2011.dropna()
print('dados limpo',lidia_final_2011.shape)

print('antes',lidia_final_2013.shape)
lidia_final_2013 = lidia_final_2013.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2013.shape)
lidia_final_2013 = lidia_final_2013.dropna()
print('dados limpo',lidia_final_2013.shape)

print('antes',lidia_final_2015.shape)
lidia_final_2015 = lidia_final_2015.dropna(axis='columns',thresh=15000)
print(lidia_final_2015.shape)
lidia_final_2015 = lidia_final_2015.dropna()
print('dados limpo',lidia_final_2015.shape)

print('antes',lidia_final_2017.shape)
lidia_final_2017 = lidia_final_2017.dropna(axis='columns',thresh=15000)
print('sem algumas colunas',lidia_final_2017.shape)
lidia_final_2017 = lidia_final_2017.dropna()
print('dados limpo',lidia_final_2017.shape)
# Out:
# antes (41759, 204)
# sem algumas colunas (41759, 189)
# dados limpo (9664, 189)
# antes (42369, 184)
# sem algumas colunas (42369, 169)
# dados limpo (28640, 169)
# antes (42784, 184)
# sem algumas colunas (42784, 170)
# dados limpo (27429, 170)
# antes (43163, 184)
# sem algumas colunas (43163, 174)
# dados limpo (11947, 174)
# antes (43378, 184)
# (43378, 173)
# dados limpo (14653, 173)
# antes (43586, 184)
# sem algumas colunas (43586, 174)
# dados limpo (5777, 174)
# antes (42784, 183)
# sem algumas colunas (42784, 169)
# dados limpo (40063, 169)
# antes (42369, 183)
# sem algumas colunas (42369, 168)
# dados limpo (41852, 168)
# antes (42784, 183)
# sem algumas colunas (42784, 169)
# dados limpo (40063, 169)
# antes (43163, 183)
# sem algumas colunas (43163, 173)
# dados limpo (15652, 173)
# antes (43378, 183)
# (43378, 172)
# dados limpo (19065, 172)
# antes (43586, 183)
# sem algumas colunas (43586, 173)
# dados limpo (6948, 173)

# %% [markdown]
# ### Alexandre

# %%
print(alexandre_inicio_2015.shape)
print(alexandre_inicio_2015.count()-alexandre_inicio_2015.shape[0])

print(alexandre_inicio_2017.shape)
print(alexandre_inicio_2017.count()-alexandre_inicio_2017.shape[0])

print(alexandre_final_2015.shape)
print(alexandre_final_2015.count()-alexandre_final_2015.shape[0])

print(alexandre_final_2017.shape)
print(alexandre_final_2017.count()-alexandre_final_2017.shape[0])
# Out:
# (12048, 47)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_infantil              0
# num_estudantes_ensino_fund_anos_iniciais    0
# num_estudantes_ensino_fund_anos_finais      0
# num_estudantes_fund_1_ano                   0
# num_estudantes_fund_2_ano                   0
# num_estudantes_fund_3_ano                   0
# num_estudantes_fund_4_ano                   0
# num_estudantes_fund_5_ano                   0
# num_estudantes_fund_6_ano                   0
# num_estudantes_fund_7_ano                   0
# num_estudantes_fund_8_ano                   0
# num_estudantes_fund_9_ano                   0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12508, 47)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_infantil              0
# num_estudantes_ensino_fund_anos_iniciais    0
# num_estudantes_ensino_fund_anos_finais      0
# num_estudantes_fund_1_ano                   0
# num_estudantes_fund_2_ano                   0
# num_estudantes_fund_3_ano                   0
# num_estudantes_fund_4_ano                   0
# num_estudantes_fund_5_ano                   0
# num_estudantes_fund_6_ano                   0
# num_estudantes_fund_7_ano                   0
# num_estudantes_fund_8_ano                   0
# num_estudantes_fund_9_ano                   0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12158, 41)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_medio_propedeutico    0
# num_estudantes_medio_1_serie                0
# num_estudantes_medio_2_serie                0
# num_estudantes_medio_3_serie                0
# num_estudantes_medio_4_serie                0
# num_estudantes_medio_nao_seriada            0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64
# (12751, 41)
# Unnamed: 0                                  0
# ano_censo                                   0
# regiao                                      0
# unidade_federativa                          0
# mesoregiao                                  0
# microregiao                                 0
# municipio                                   0
# cod_municipio                               0
# num_escolas                                 0
# num_escolas_em_atividade                    0
# num_estudantes_ensino_medio_propedeutico    0
# num_estudantes_medio_1_serie                0
# num_estudantes_medio_2_serie                0
# num_estudantes_medio_3_serie                0
# num_estudantes_medio_4_serie                0
# num_estudantes_medio_nao_seriada            0
# num_salas_existentes                        0
# num_salas_utilizadas                        0
# num_equip_tv                                0
# num_equip_videocassete                      0
# num_equip_dvd                               0
# num_equip_parabolica                        0
# num_equip_copiadora                         0
# num_equip_retroprojetor                     0
# num_equip_impressora                        0
# num_equip_impressora_mult                   0
# num_equip_som                               0
# num_equip_multimidia                        0
# num_equip_fax                               0
# num_equip_foto                              0
# num_computador                              0
# num_comp_administrativo                     0
# num_comp_aluno                              0
# num_funcionarios                            0
# num_escolas_rurais                          0
# num_escolas_urbanas                         0
# num_professores                             0
# num_matriculas                              0
# num_estudantes                              0
# num_turmas                                  0
# ideb                                        0
# dtype: int64

# %% [markdown]
# ### William

# %%
print(william_inicio_2007.shape)
print(william_inicio_2007.count()-william_inicio_2007.shape[0])

print(william_inicio_2009.shape)
print(william_inicio_2009.count()-william_inicio_2009.shape[0])

print(william_inicio_2011.shape)
print(william_inicio_2011.count()-william_inicio_2011.shape[0])

print(william_inicio_2013.shape)
print(william_inicio_2013.count()-william_inicio_2013.shape[0])

print(william_inicio_2015.shape)
print(william_inicio_2015.count()-william_inicio_2015.shape[0])

print(william_inicio_2017.shape)
print(william_inicio_2017.count()-william_inicio_2017.shape[0])

print(william_final_2007.shape)
print(william_final_2007.count()-william_final_2007.shape[0])

print(william_final_2009.shape)
print(william_final_2009.count()-william_final_2009.shape[0])

print(william_final_2011.shape)
print(william_final_2011.count()-william_final_2011.shape[0])

print(william_final_2013.shape)
print(william_final_2013.count()-william_final_2013.shape[0])

print(william_final_2015.shape)
print(william_final_2015.count()-william_final_2015.shape[0])

print(william_final_2017.shape)
print(william_final_2017.count()-william_final_2017.shape[0])
# Out:
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (120, 16)
# Unnamed: 0                           0
# index                                0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 15)
# Unnamed: 0                           0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (127, 16)
# Unnamed: 0                           0
# index                                0
# UF_REG                               0
# Rede                                 0
# TaxaAprovacao_1ao5ano                0
# TaxaAprovacao_1ano                   0
# TaxaAprovacao_2ano                   0
# TaxaAprovacao_3ano                   0
# TaxaAprovacao_4ano                   0
# TaxaAprovacao_5ano                   0
# IndicadorRendimento_inicial          0
# NotaProvaBrasil_MT_inicial           0
# NotaProvaBrasil_LP_inicial           0
# NotaProvaBrasil_NotaMedia_inicial    0
# Ideb                                 0
# ProjecaoIdeb_inicial                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (121, 15)
# Unnamed: 0                          0
# index                               0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64
# (128, 14)
# Unnamed: 0                          0
# UF_REG                              0
# Rede                                0
# TaxaAprovacao_6ao9ano               0
# TaxaAprovacao_6ano                  0
# TaxaAprovacao_7ano                  0
# TaxaAprovacao_8ano                  0
# TaxaAprovacao_9ano                  0
# IndicadorRendimento_finais          0
# NotaProvaBrasil_MT_finais           0
# NotaProvaBrasil_LP_finais           0
# NotaProvaBrasil_NotaMedia_finais    0
# Ideb                                0
# ProjecaoIdeb_finais                 0
# dtype: int64

# %% [markdown]
# # Correlação

# %% [markdown]
# ### Lidia

# %%
lidia_corr__inicio_2007 = calculate_pearson(lidia_inicio_2007)
lidia_corr__inicio_2007 = lidia_corr__inicio_2007.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2009 = calculate_pearson(lidia_inicio_2009)
lidia_corr__inicio_2009 = lidia_corr__inicio_2009.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2011 = calculate_pearson(lidia_inicio_2011)
lidia_corr__inicio_2011 = lidia_corr__inicio_2011.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2013 = calculate_pearson(lidia_inicio_2013)
lidia_corr__inicio_2013 = lidia_corr__inicio_2013.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2015 = calculate_pearson(lidia_inicio_2015)
lidia_corr__inicio_2015 = lidia_corr__inicio_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__inicio_2017 = calculate_pearson(lidia_inicio_2017)
lidia_corr__inicio_2017 = lidia_corr__inicio_2017.sort_values(by=['correlation_with_ideb'], ascending=False)

lidia_corr__final_2007 = calculate_pearson(lidia_final_2007)
lidia_corr__final_2007 = lidia_corr__final_2007.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2009 = calculate_pearson(lidia_final_2009)
lidia_corr__final_2009 = lidia_corr__final_2009.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2011 = calculate_pearson(lidia_final_2011)
lidia_corr__final_2011 = lidia_corr__final_2011.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2013 = calculate_pearson(lidia_final_2013)
lidia_corr__final_2013 = lidia_corr__final_2013.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2015 = calculate_pearson(lidia_final_2015)
lidia_corr__final_2015 = lidia_corr__final_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
lidia_corr__final_2017 = calculate_pearson(lidia_final_2017)
lidia_corr__final_2017 = lidia_corr__final_2017.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
# C:\Users\William\Anaconda3\lib\site-packages\scipy\stats\stats.py:3003: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# C:\Users\William\Anaconda3\lib\site-packages\scipy\stats\stats.py:5240: RuntimeWarning: invalid value encountered in less
#   x = np.where(x < 1.0, x, 1.0)  # if x > 1 then return 1.0

# %%
print(lidia_corr__inicio_2007)
print(lidia_corr__inicio_2009)
print(lidia_corr__inicio_2011)
print(lidia_corr__inicio_2013)
print(lidia_corr__inicio_2015)
print(lidia_corr__inicio_2017)
# Out:
#                             feature  correlation_with_ideb
# 174                            ideb               1.000000
# 1                      Unnamed: 0.1               0.537197
# 0                        Unnamed: 0               0.537197
# 144         ideb_2013_anos_iniciais               0.528504
# 140         ideb_2013_ai_media_port               0.524285
# 142       ideb_2013_ai_proficiencia               0.519969
# 141          ideb_2013_ai_media_mat               0.505612
# 150         ideb_2015_ai_media_port               0.483675
# 154         ideb_2015_anos_iniciais               0.472666
# 152       ideb_2015_ai_proficiencia               0.471025
# 151          ideb_2015_ai_media_mat               0.443483
# 147       ideb_2013_af_proficiencia               0.420138
# 145         ideb_2013_af_media_port               0.414646
# 157       ideb_2015_af_proficiencia               0.411284
# 146          ideb_2013_af_media_mat               0.407111
# 156          ideb_2015_af_media_mat               0.402166
# 149           ideb_2013_anos_finais               0.396607
# 155         ideb_2015_af_media_port               0.396309
# 159           ideb_2015_anos_finais               0.366991
# 131                     in_internet               0.353571
# 61           in_esgoto_rede_publica               0.349012
# 143              ideb_2013_ai_fluxo               0.345682
# 3                   cod_escola_inep               0.340136
# 172                     cod_ibge_uf               0.339936
# 64         in_lixo_coleta_periodica               0.333688
# 52             in_agua_rede_publica               0.330027
# 153              ideb_2015_ai_fluxo               0.316351
# 108          in_equip_retroprojetor               0.296575
# 107              in_equip_copiadora               0.287850
# 77               in_quadra_esportes               0.267280
# ..                              ...                    ...
# 78                       in_cozinha               0.017329
# 100          in_dependencias_outras               0.005189
# 25        num_estudantes_fund_6_ano               0.004145
# 40      in_local_func_salas_empresa              -0.004249
# 42     in_local_func_unid_prisional              -0.009235
# 44      in_local_func_templo_igreja              -0.010202
# 32     num_estudantes_medio_4_serie              -0.016149
# 60           in_energia_inexistente              -0.023504
# 56              in_agua_inexistente              -0.033491
# 45     in_local_func_casa_professor              -0.039466
# 48    in_local_func_salas_outra_esc              -0.041796
# 167            in_educacao_indigena              -0.049447
# 68                  in_lixo_enterra              -0.053564
# 58               in_energia_gerador              -0.059180
# 59                in_energia_outros              -0.061225
# 50          in_predio_compartilhado              -0.063514
# 63            in_esgoto_inexistente              -0.065991
# 16   num_estudantes_ensino_infantil              -0.079739
# 51                 in_agua_filtrada              -0.088172
# 47               tp_ocupacao_galpao              -0.090553
# 49             in_local_func_outros              -0.094738
# 55                in_agua_fonte_rio              -0.100079
# 66          in_lixo_joga_outra_area              -0.141284
# 163     tp_localizacao_diferenciada              -0.147959
# 54                  in_agua_cacimba              -0.186996
# 53           in_agua_poco_artesiano              -0.216736
# 4                    tp_dependencia              -0.245464
# 65                   in_lixo_queima              -0.302359
# 62                  in_esgoto_fossa              -0.327050
# 37                   tp_localizacao              -0.730676
#
# [110 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 154                                      ideb               1.000000
# 137       num_professores_em_regencia_fund_ai               0.487514
# 24                  num_estudantes_fund_5_ano               0.452148
# 17   num_estudantes_ensino_fund_anos_iniciais               0.426481
# 23                  num_estudantes_fund_4_ano               0.369853
# 22                  num_estudantes_fund_3_ano               0.351902
# 101                      num_salas_existentes               0.341334
# 131                               in_internet               0.339687
# 64                   in_lixo_coleta_periodica               0.334990
# 21                  num_estudantes_fund_2_ano               0.334964
# 135                           num_professores               0.334780
# 136               num_professores_em_regencia               0.333911
# 34                                 num_turmas               0.320369
# 102                      num_salas_utilizadas               0.311338
# 133                          num_funcionarios               0.305220
# 20                  num_estudantes_fund_1_ano               0.304434
# 132                            in_banda_larga               0.298161
# 61                     in_esgoto_rede_publica               0.291567
# 77                         in_quadra_esportes               0.291155
# 7                              num_matriculas               0.281248
# 109                       in_equip_impressora               0.279888
# 71                          in_sala_professor               0.279303
# 8                              num_estudantes               0.277290
# 107                        in_equip_copiadora               0.274553
# 108                    in_equip_retroprojetor               0.274280
# 3                             cod_escola_inep               0.269599
# 152                               cod_ibge_uf               0.269225
# 115                             in_computador               0.260622
# 52                       in_agua_rede_publica               0.258704
# 72                 in_laboratorio_informatica               0.238747
# ..                                        ...                    ...
# 40                in_local_func_salas_empresa              -0.000206
# 69                             in_lixo_outros              -0.006106
# 56                        in_agua_inexistente              -0.006585
# 6             in_somente_matriculas_ac_ou_aee              -0.014495
# 44                in_local_func_templo_igreja              -0.019021
# 144                in_material_esp_quilombola              -0.022917
# 100                    in_dependencias_outras              -0.025173
# 50                    in_predio_compartilhado              -0.033512
# 84                    in_banheiro_fora_predio              -0.034150
# 45               in_local_func_casa_professor              -0.037044
# 49                       in_local_func_outros              -0.043590
# 59                          in_energia_outros              -0.049252
# 63                      in_esgoto_inexistente              -0.059868
# 47                         tp_ocupacao_galpao              -0.062852
# 145                  in_material_esp_indigena              -0.066050
# 68                            in_lixo_enterra              -0.066730
# 147                      in_educacao_indigena              -0.088574
# 60                     in_energia_inexistente              -0.091704
# 58                         in_energia_gerador              -0.094226
# 55                          in_agua_fonte_rio              -0.109103
# 143               tp_localizacao_diferenciada              -0.109236
# 4                              tp_dependencia              -0.114244
# 66                    in_lixo_joga_outra_area              -0.114461
# 54                            in_agua_cacimba              -0.145839
# 53                     in_agua_poco_artesiano              -0.147765
# 62                            in_esgoto_fossa              -0.274690
# 65                             in_lixo_queima              -0.294661
# 37                             tp_localizacao              -0.353150
# 1                                Unnamed: 0.1              -0.445186
# 0                                  Unnamed: 0              -0.445186
#
# [100 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 155                                      ideb               1.000000
# 137       num_professores_em_regencia_fund_ai               0.521066
# 24                  num_estudantes_fund_5_ano               0.501985
# 17   num_estudantes_ensino_fund_anos_iniciais               0.481464
# 23                  num_estudantes_fund_4_ano               0.454035
# 21                  num_estudantes_fund_2_ano               0.401783
# 22                  num_estudantes_fund_3_ano               0.390021
# 20                  num_estudantes_fund_1_ano               0.375847
# 34                                 num_turmas               0.281500
# 102                      num_salas_utilizadas               0.260978
# 136               num_professores_em_regencia               0.256260
# 135                           num_professores               0.252930
# 133                          num_funcionarios               0.251840
# 7                              num_matriculas               0.237217
# 8                              num_estudantes               0.235074
# 61                     in_esgoto_rede_publica               0.230482
# 64                   in_lixo_coleta_periodica               0.219332
# 101                      num_salas_existentes               0.215001
# 131                               in_internet               0.200869
# 142                     in_fundamental_ciclos               0.196938
# 132                            in_banda_larga               0.191240
# 75                 in_quadra_esportes_coberta               0.188384
# 107                        in_equip_copiadora               0.178230
# 52                       in_agua_rede_publica               0.176558
# 108                    in_equip_retroprojetor               0.167621
# 71                          in_sala_professor               0.164504
# 141                 tp_atividade_complementar               0.160674
# 140                                    tp_aee               0.159717
# 3                             cod_escola_inep               0.157453
# 153                               cod_ibge_uf               0.156968
# ..                                        ...                    ...
# 6             in_somente_matriculas_ac_ou_aee              -0.013221
# 59                          in_energia_outros              -0.014167
# 33           num_estudantes_medio_nao_seriada              -0.014662
# 106                       in_equip_parabolica              -0.019437
# 69                             in_lixo_outros              -0.020971
# 47                         tp_ocupacao_galpao              -0.021484
# 145                  in_material_esp_indigena              -0.022288
# 45               in_local_func_casa_professor              -0.025117
# 144                in_material_esp_quilombola              -0.025432
# 50                    in_predio_compartilhado              -0.029020
# 63                      in_esgoto_inexistente              -0.031463
# 147                      in_educacao_indigena              -0.035457
# 139     num_professores_em_regencia_ens_medio              -0.035815
# 29               num_estudantes_medio_1_serie              -0.041672
# 58                         in_energia_gerador              -0.042749
# 30               num_estudantes_medio_2_serie              -0.044678
# 19   num_estudantes_ensino_medio_propedeutico              -0.045593
# 31               num_estudantes_medio_3_serie              -0.052573
# 56                        in_agua_inexistente              -0.054342
# 55                          in_agua_fonte_rio              -0.062035
# 68                            in_lixo_enterra              -0.063120
# 66                    in_lixo_joga_outra_area              -0.074852
# 143               tp_localizacao_diferenciada              -0.082004
# 54                            in_agua_cacimba              -0.100325
# 53                     in_agua_poco_artesiano              -0.107742
# 65                             in_lixo_queima              -0.190972
# 62                            in_esgoto_fossa              -0.221417
# 37                             tp_localizacao              -0.248462
# 1                                Unnamed: 0.1              -0.334343
# 0                                  Unnamed: 0              -0.334343
#
# [102 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 158                                      ideb               1.000000
# 24                  num_estudantes_fund_5_ano               0.531190
# 138       num_professores_em_regencia_fund_ai               0.487543
# 17   num_estudantes_ensino_fund_anos_iniciais               0.475902
# 23                  num_estudantes_fund_4_ano               0.448017
# 22                  num_estudantes_fund_3_ano               0.400929
# 21                  num_estudantes_fund_2_ano               0.396181
# 20                  num_estudantes_fund_1_ano               0.392300
# 102                      num_salas_existentes               0.237512
# 103                      num_salas_utilizadas               0.217967
# 64                   in_lixo_coleta_periodica               0.216075
# 82                         in_parque_infantil               0.206288
# 34                                 num_turmas               0.190511
# 141                                    tp_aee               0.183314
# 134                          num_funcionarios               0.179057
# 3                             cod_escola_inep               0.174370
# 156                               cod_ibge_uf               0.174006
# 136                           num_professores               0.173707
# 74               in_sala_atendimento_especial               0.173052
# 137               num_professores_em_regencia               0.172858
# 125                             num_equip_som               0.172618
# 132                               in_internet               0.166472
# 75                 in_quadra_esportes_coberta               0.162927
# 123                      num_equip_impressora               0.160269
# 133                            in_banda_larga               0.158749
# 61                     in_esgoto_rede_publica               0.157674
# 52                       in_agua_rede_publica               0.157366
# 8                              num_estudantes               0.154707
# 71                          in_sala_professor               0.153498
# 86                             in_banheiro_ei               0.146086
# ..                                        ...                    ...
# 107                       in_equip_parabolica              -0.014619
# 60                     in_energia_inexistente              -0.016690
# 50                    in_predio_compartilhado              -0.017164
# 58                         in_energia_gerador              -0.021294
# 145                in_material_esp_quilombola              -0.021864
# 148                      in_educacao_indigena              -0.022636
# 59                          in_energia_outros              -0.022934
# 146                  in_material_esp_indigena              -0.024202
# 47                         tp_ocupacao_galpao              -0.025185
# 27                  num_estudantes_fund_8_ano              -0.025328
# 80                            in_sala_leitura              -0.026501
# 98                        in_alojam_professor              -0.028963
# 33           num_estudantes_medio_nao_seriada              -0.036699
# 28                  num_estudantes_fund_9_ano              -0.040172
# 63                      in_esgoto_inexistente              -0.041291
# 55                          in_agua_fonte_rio              -0.053079
# 68                            in_lixo_enterra              -0.054713
# 56                        in_agua_inexistente              -0.061933
# 144               tp_localizacao_diferenciada              -0.071345
# 54                            in_agua_cacimba              -0.079048
# 66                    in_lixo_joga_outra_area              -0.080926
# 53                     in_agua_poco_artesiano              -0.081757
# 29               num_estudantes_medio_1_serie              -0.098270
# 30               num_estudantes_medio_2_serie              -0.101921
# 19   num_estudantes_ensino_medio_propedeutico              -0.106599
# 140     num_professores_em_regencia_ens_medio              -0.110662
# 31               num_estudantes_medio_3_serie              -0.111384
# 62                            in_esgoto_fossa              -0.141228
# 65                             in_lixo_queima              -0.186703
# 37                             tp_localizacao              -0.228842
#
# [134 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 157                                      ideb               1.000000
# 137       num_professores_em_regencia_fund_ai               0.572594
# 24                  num_estudantes_fund_5_ano               0.566457
# 17   num_estudantes_ensino_fund_anos_iniciais               0.560409
# 11                           in_comum_fund_ai               0.550724
# 23                  num_estudantes_fund_4_ano               0.526113
# 22                  num_estudantes_fund_3_ano               0.499464
# 21                  num_estudantes_fund_2_ano               0.499401
# 20                  num_estudantes_fund_1_ano               0.479569
# 34                                 num_turmas               0.329714
# 101                      num_salas_existentes               0.294192
# 102                      num_salas_utilizadas               0.286437
# 7                              num_matriculas               0.284327
# 135                           num_professores               0.280975
# 136               num_professores_em_regencia               0.275764
# 8                              num_estudantes               0.273753
# 133                          num_funcionarios               0.269667
# 63                   in_lixo_coleta_periodica               0.257608
# 74                 in_quadra_esportes_coberta               0.240256
# 129                   num_comp_administrativo               0.235977
# 81                         in_parque_infantil               0.223951
# 76                         in_quadra_esportes               0.222498
# 140                                    tp_aee               0.219928
# 3                             cod_escola_inep               0.215542
# 155                               cod_ibge_uf               0.215107
# 73               in_sala_atendimento_especial               0.212958
# 128                            num_computador               0.211561
# 124                             num_equip_som               0.208246
# 60                     in_esgoto_rede_publica               0.207423
# 51                       in_agua_rede_publica               0.184377
# ..                                        ...                    ...
# 58                          in_energia_outros              -0.024294
# 96                            in_alojam_aluno              -0.028837
# 46                       in_local_func_galpao              -0.033805
# 49                    in_predio_compartilhado              -0.035220
# 148                        tp_indigena_lingua              -0.037077
# 147                      in_educacao_indigena              -0.037585
# 119                      num_equip_parabolica              -0.044012
# 106                       in_equip_parabolica              -0.044530
# 10                               in_comum_pre              -0.044925
# 57                         in_energia_gerador              -0.048582
# 62                      in_esgoto_inexistente              -0.052612
# 12                           in_comum_fund_af              -0.053153
# 97                        in_alojam_professor              -0.056175
# 67                            in_lixo_enterra              -0.058481
# 9                             in_comum_creche              -0.068860
# 53                            in_agua_cacimba              -0.070321
# 54                          in_agua_fonte_rio              -0.070719
# 55                        in_agua_inexistente              -0.076809
# 65                    in_lixo_joga_outra_area              -0.085721
# 30               num_estudantes_medio_2_serie              -0.089459
# 29               num_estudantes_medio_1_serie              -0.091618
# 31               num_estudantes_medio_3_serie              -0.092971
# 19   num_estudantes_ensino_medio_propedeutico              -0.093006
# 143               tp_localizacao_diferenciada              -0.097479
# 52                     in_agua_poco_artesiano              -0.106080
# 139     num_professores_em_regencia_ens_medio              -0.107445
# 13                       in_comum_medio_medio              -0.136577
# 61                            in_esgoto_fossa              -0.190499
# 64                             in_lixo_queima              -0.242870
# 37                             tp_localizacao              -0.265421
#
# [148 rows x 2 columns]
#                                       feature  correlation_with_ideb
# 157                                      ideb               1.000000
# 11                           in_comum_fund_ai               0.623850
# 1                                Unnamed: 0.1               0.511451
# 0                                  Unnamed: 0               0.511451
# 137       num_professores_em_regencia_fund_ai               0.378488
# 24                  num_estudantes_fund_5_ano               0.339761
# 17   num_estudantes_ensino_fund_anos_iniciais               0.334839
# 23                  num_estudantes_fund_4_ano               0.331921
# 21                  num_estudantes_fund_2_ano               0.304710
# 20                  num_estudantes_fund_1_ano               0.294467
# 22                  num_estudantes_fund_3_ano               0.283709
# 81                         in_parque_infantil               0.171117
# 4                              tp_dependencia               0.157467
# 124                             num_equip_som               0.123444
# 129                   num_comp_administrativo               0.121716
# 74                 in_quadra_esportes_coberta               0.121699
# 10                               in_comum_pre               0.117842
# 9                             in_comum_creche               0.117165
# 16             num_estudantes_ensino_infantil               0.116986
# 99                              in_lavanderia               0.115512
# 85                             in_banheiro_ei               0.100814
# 66                            in_lixo_recicla               0.095151
# 76                         in_quadra_esportes               0.093665
# 3                             cod_escola_inep               0.093564
# 155                               cod_ibge_uf               0.093361
# 90                              in_refeitorio               0.089151
# 111                              in_equip_som               0.086015
# 102                      num_salas_utilizadas               0.082800
# 130                            num_comp_aluno               0.077951
# 128                            num_computador               0.076889
# ..                                        ...                    ...
# 64                             in_lixo_queima              -0.024097
# 97                        in_alojam_professor              -0.025603
# 79                            in_sala_leitura              -0.026457
# 151                   in_formacao_alternancia              -0.027236
# 52                     in_agua_poco_artesiano              -0.029626
# 150                           in_final_semana              -0.034666
# 143               tp_localizacao_diferenciada              -0.036434
# 42               in_local_func_unid_prisional              -0.039845
# 39                 tp_ocupacao_predio_escolar              -0.040570
# 153            num_estudantes_ensino_integral              -0.040975
# 152            num_matriculas_ensino_integral              -0.040979
# 43              in_local_func_prisional_socio              -0.041547
# 15                      in_comum_medio_normal              -0.044262
# 14                   in_comum_medio_integrado              -0.046167
# 12                           in_comum_fund_af              -0.046977
# 61                            in_esgoto_fossa              -0.054326
# 147                      in_educacao_indigena              -0.055040
# 148                        tp_indigena_lingua              -0.057275
# 29               num_estudantes_medio_1_serie              -0.117559
# 139     num_professores_em_regencia_ens_medio              -0.118089
# 30               num_estudantes_medio_2_serie              -0.123732
# 31               num_estudantes_medio_3_serie              -0.124683
# 19   num_estudantes_ensino_medio_propedeutico              -0.125793
# 13                       in_comum_medio_medio              -0.127456
# 138       num_professores_em_regencia_fund_af              -0.139396
# 27                  num_estudantes_fund_8_ano              -0.143706
# 28                  num_estudantes_fund_9_ano              -0.144691
# 25                  num_estudantes_fund_6_ano              -0.156313
# 26                  num_estudantes_fund_7_ano              -0.160073
# 18     num_estudantes_ensino_fund_anos_finais              -0.163365
#
# [145 rows x 2 columns]

# %% [markdown]
# print(lidia_corr__final_2007)
# print(lidia_corr__final_2009)
# print(lidia_corr__final_2011)
# print(lidia_corr__final_2013)
# print(lidia_corr__final_2015)
# print(lidia_corr__final_2017)

# %% [markdown]
# ### Variaveis categoricas

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[0]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[3]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[7]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[8]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[9]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[10]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[11]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[12]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
var = calculate_categorical_correlation(lidia_inicio_2007)[6]
data = pd.concat([lidia_inicio_2007['ideb'], lidia_inicio_2007[var]], axis=1)
f, ax = plt.subplots(figsize=(10, 10))

fig = sns.boxplot( x=var,y="ideb", data=data)
fig.axis(ymin=0, ymax=10);

# %%
print('Before getting dummys',lidia_inicio_2007.shape)
lidia_inicio_2007 = pd.get_dummies(lidia_inicio_2007)
print('after getting dummys',lidia_inicio_2007.shape)
# Out:
# Before getting dummys (9664, 189)
# after getting dummys (9664, 16038)

# %%
y = lidia_inicio_2007['ideb']
x = lidia_inicio_2007.drop(columns=['ideb'])

# %%
# Partition the dataset in train + validation sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state=1)

# %%
# Define error measure for official scoring : RMSE
scorer = make_scorer(mean_squared_error, greater_is_better = False)

def rmse_cv_train(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, scoring = scorer, cv = 5))
    return(rmse)

def rmse_cv_test(model):
    rmse= np.sqrt(-cross_val_score(model, X_test, y_test, scoring = scorer, cv = 5))
    return(rmse)

# %% [markdown]
# # Ridge Regression

# %%
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60])
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)
# Out:
# Best alpha : 6.0

# %%
print("Try again for more precision with alphas centered around " + str(alpha))
ridge = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 10)
ridge.fit(X_train, y_train)
alphaRidge = ridge.alpha_
print("Best alpha :", alphaRidge)
# Out:
# Try again for more precision with alphas centered around 6.0
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\William\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "

# %%
ridge = make_pipeline(StandardScaler(), Ridge(alpha = alphaRidge, random_state=1))
ridge.fit(X_train, y_train)

# %%
print("Ridge RMSE on Training set :", rmse_cv_train(ridge).mean())
print("Ridge RMSE on Training error :", rmse_cv_train(ridge).std())
print("Ridge RMSE on Test set :", rmse_cv_test(ridge).mean())
print("Ridge RMSE on Test error :", rmse_cv_test(ridge).std())
y_train_rdg = ridge.predict(X_train)
y_test_rdg = ridge.predict(X_test)

# %%
# Plot residuals
plt.scatter(y_train_rdg, y_train_rdg - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test_rdg - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# %%
# Plot important coefficients
coefs = pd.Series(ridge.coef_, index = X_train.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Ridge Model")
plt.show()
