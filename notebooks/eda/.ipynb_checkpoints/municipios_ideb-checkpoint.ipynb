# %% [markdown]
# Esse notebook faz a junção de cada dataset de município com a coluna do `ideb` do dataset do ideb. O objetivo dessa junção é analisar como as variáveis de municípios impactam no ideb, que é a nossa variável resposta.

# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Carrega Datasets

# %%
df_municipios_2015 = pd.read_csv('../../data/bcggammachallenge/municipios/municipios20150101.csv')
df_municipios_2016 = pd.read_csv('../../data/bcggammachallenge/municipios/municipios20160101.csv')
df_municipios_2017 = pd.read_csv('../../data/bcggammachallenge/municipios/municipios20170101.csv')

# %%
df = pd.concat([df_municipios_2015, df_municipios_2016, df_municipios_2017])

# %%
df_municipios_2017.shape
# Out:
# (5570, 51)

# %%
df.head()
# Out:
#    ano_censo   regiao unidade_federativa mesoregiao microregiao  \
# 0       2015  Sudeste          São Paulo      Assis       Assis
# 1       2015  Sudeste          São Paulo      Assis       Assis
# 2       2015  Sudeste          São Paulo      Assis       Assis
# 3       2015  Sudeste          São Paulo      Assis       Assis
# 4       2015  Sudeste          São Paulo      Assis       Assis
#
#                municipio  cod_municipio  num_escolas  \
# 0                 Nantes        3532157            3
# 1                 Tarumã        3553955           10
# 2               Cruzália        3513306            5
# 3  Campos Novos Paulista        3509809            3
# 4                  Assis        3504008           75
#
#    num_escolas_em_atividade  num_estudantes_ensino_infantil  \
# 0                         3                             167
# 1                        10                             971
# 2                         3                             103
# 3                         3                             202
# 4                        70                            5052
#
#    num_estudantes_ensino_fund_anos_iniciais  \
# 0                                       168
# 1                                      1053
# 2                                       105
# 3                                       334
# 4                                      6126
#
#    num_estudantes_ensino_fund_anos_finais  \
# 0                                     170
# 1                                     852
# 2                                      93
# 3                                     312
# 4                                    5002
#
#    num_estudantes_ensino_medio_propedeutico  num_estudantes_fund_1_ano  \
# 0                                       141                         37
# 1                                       483                        210
# 2                                        84                         33
# 3                                       167                         62
# 4                                      3323                       1256
#
#    num_estudantes_fund_2_ano  num_estudantes_fund_3_ano  \
# 0                         32                         34
# 1                        209                        218
# 2                         18                         23
# 3                         59                         90
# 4                       1306                       1237
#
#    num_estudantes_fund_4_ano  num_estudantes_fund_5_ano  \
# 0                         19                         46
# 1                        225                        191
# 2                         21                         10
# 3                         63                         60
# 4                       1194                       1133
#
#    num_estudantes_fund_6_ano  num_estudantes_fund_7_ano  \
# 0                         31                         45
# 1                        211                        216
# 2                         21                         17
# 3                         96                         64
# 4                       1430                       1053
#
#    num_estudantes_fund_8_ano  num_estudantes_fund_9_ano  \
# 0                         58                         36
# 1                        208                        217
# 2                         26                         29
# 3                         78                         74
# 4                       1198                       1321
#
#    num_estudantes_medio_1_serie  num_estudantes_medio_2_serie  \
# 0                            43                            53
# 1                           187                           171
# 2                            29                            30
# 3                            69                            55
# 4                          1216                          1087
#
#    num_estudantes_medio_3_serie  num_estudantes_medio_4_serie  \
# 0                            45                             0
# 1                           125                             0
# 2                            25                             0
# 3                            43                             0
# 4                          1020                             0
#
#    num_estudantes_medio_nao_seriada  num_salas_existentes  \
# 0                                 0                    19
# 1                                 0                   117
# 2                                 0                    18
# 3                                 0                    26
# 4                                 0                   842
#
#    num_salas_utilizadas  num_equip_tv  num_equip_videocassete  num_equip_dvd  \
# 0                    19             3                       1              2
# 1                   117             9                       0              9
# 2                    18             3                       1              3
# 3                    26             3                       0              3
# 4                   897            67                      28             59
#
#    num_equip_parabolica  num_equip_copiadora  num_equip_retroprojetor  \
# 0                     1                    2                        1
# 1                     3                    6                        2
# 2                     1                    2                        1
# 3                     0                    3                        2
# 4                    14                   22                       42
#
#    num_equip_impressora  num_equip_impressora_mult  num_equip_som  \
# 0                     3                          2              2
# 1                     9                          8              9
# 2                     2                          1              3
# 3                     3                          2              2
# 4                    67                         49             67
#
#    num_equip_multimidia  num_equip_fax  num_equip_foto  num_computador  \
# 0                     1              0               2               3
# 1                     8              2               8              10
# 2                     2              1               2               3
# 3                     2              2               2               3
# 4                    56             29              62              68
#
#    num_comp_administrativo  num_comp_aluno  num_funcionarios  \
# 0                        3               1                89
# 1                       10               8               458
# 2                        3               1                54
# 3                        3               3               133
# 4                       66              53              3288
#
#    num_escolas_rurais  num_escolas_urbanas  num_professores  num_matriculas  \
# 0                   0                    0               44             782
# 1                   0                    0              257            3880
# 2                   0                    0               44             590
# 3                   0                    0               77            1131
# 4                   0                    0             1417           25237
#
#    num_estudantes  num_turmas
# 0             676          45
# 1            3473         181
# 2             405          37
# 3            1015          61
# 4           22096        1134

# %%
df_ideb_ini = pd.read_csv('../../data/bcggammachallenge/ideb/ideb_municipios_anosiniciais2005_2017.csv',sep = ',',encoding='latin-1')
df_ideb_fin = pd.read_csv('../../data/bcggammachallenge/ideb/ideb_municipios_anosfinais2005_2017.csv',sep = ',',encoding='latin-1')

# %%
df_ideb_ini.shape
# Out:
# (14436, 89)

# %%
df_ideb_ini.columns
# Out:
# Index(['Co_UF', 'Cod_Municipio_Completo', 'Nome_Municipio', 'Rede',
#        'TaxaAprovacao2005_1ao5ano', 'TaxaAprovacao2005_1ano',
#        'TaxaAprovacao2005_2ano', 'TaxaAprovacao2005_3ano',
#        'TaxaAprovacao2005_4ano', 'TaxaAprovacao2005_5ano',
#        'IndicadorRendimento_2005', 'TaxaAprovacao2007_1ao5ano',
#        'TaxaAprovacao2007_1ano', 'TaxaAprovacao2007_2ano',
#        'TaxaAprovacao2007_3ano', 'TaxaAprovacao2007_4ano',
#        'TaxaAprovacao2007_5ano', 'IndicadorRendimento_2007',
#        'TaxaAprovacao2009_1ao5ano', 'TaxaAprovacao2009_1ano',
#        'TaxaAprovacao2009_2ano', 'TaxaAprovacao2009_3ano',
#        'TaxaAprovacao2009_4ano', 'TaxaAprovacao2009_5ano',
#        'IndicadorRendimento_2009', 'TaxaAprovacao2011_1ao5ano',
#        'TaxaAprovacao2011_1ano', 'TaxaAprovacao2011_2ano',
#        'TaxaAprovacao2011_3ano', 'TaxaAprovacao2011_4ano',
#        'TaxaAprovacao2011_5ano', 'IndicadorRendimento_2011',
#        'TaxaAprovacao2013_1ao5ano', 'TaxaAprovacao2013_1ano',
#        'TaxaAprovacao2013_2ano', 'TaxaAprovacao2013_3ano',
#        'TaxaAprovacao2013_4ano', 'TaxaAprovacao2013_5ano',
#        'IndicadorRendimento_2013', 'TaxaAprovacao2015_1ao5ano',
#        'TaxaAprovacao2015_1ano', 'TaxaAprovacao2015_2ano',
#        'TaxaAprovacao2015_3ano', 'TaxaAprovacao2015_4ano',
#        'TaxaAprovacao2015_5ano', 'IndicadorRendimento_2015',
#        'TaxaAprovacao2017_1ao5ano', 'TaxaAprovacao2017_1ano',
#        'TaxaAprovacao2017_2ano', 'TaxaAprovacao2017_3ano',
#        'TaxaAprovacao2017_4ano', 'TaxaAprovacao2017_5ano',
#        'IndicadorRendimento_2017', 'NotaProvaBrasil_MT_2005',
#        'NotaProvaBrasil_LP_2005', 'NotaProvaBrasil_NotaMedia_2005',
#        'NotaProvaBrasil_MT_2007', 'NotaProvaBrasil_LP_2007',
#        'NotaProvaBrasil_NotaMedia_2007', 'NotaProvaBrasil_MT_2009',
#        'NotaProvaBrasil_LP_2009', 'NotaProvaBrasil_NotaMedia_2009',
#        'NotaProvaBrasil_MT_2011', 'NotaProvaBrasil_LP_2011',
#        'NotaProvaBrasil_NotaMedia_2011', 'NotaProvaBrasil_MT_2013',
#        'NotaProvaBrasil_LP_2013', 'NotaProvaBrasil_NotaMedia_2013',
#        'NotaProvaBrasil_MT_2015', 'NotaProvaBrasil_LP_2015',
#        'NotaProvaBrasil_NotaMedia_2015', 'NotaProvaBrasil_MT_2017',
#        'NotaProvaBrasil_LP_2017', 'NotaProvaBrasil_NotaMedia_2017', 'Ideb2005',
#        'Ideb2007', 'Ideb2009', 'Ideb2011', 'Ideb2013', 'Ideb2015', 'Ideb2017',
#        'ProjecaoIdeb2007', 'ProjecaoIdeb2009', 'ProjecaoIdeb2011',
#        'ProjecaoIdeb2013', 'ProjecaoIdeb2015', 'ProjecaoIdeb2017',
#        'ProjecaoIdeb2019', 'ProjecaoIdeb2021'],
#       dtype='object')

# %%
df_ideb_fin.columns
# Out:
# Index(['Co_UF', 'Cod_Municipio_Completo', 'Nome_Municipio', 'Rede',
#        'TaxaAprovacao2005_6ao9ano', 'TaxaAprovacao2005_6ano',
#        'TaxaAprovacao2005_7ano', 'TaxaAprovacao2005_8ano',
#        'TaxaAprovacao2005_9ano', 'IndicadorRendimento_2005',
#        'TaxaAprovacao2007_6ao9ano', 'TaxaAprovacao2007_6ano',
#        'TaxaAprovacao2007_7ano', 'TaxaAprovacao2007_8ano',
#        'TaxaAprovacao2007_9ano', 'IndicadorRendimento_2007',
#        'TaxaAprovacao2009_6ao9ano', 'TaxaAprovacao2009_6ano',
#        'TaxaAprovacao2009_7ano', 'TaxaAprovacao2009_8ano',
#        'TaxaAprovacao2009_9ano', 'IndicadorRendimento_2009',
#        'TaxaAprovacao2011_6ao9ano', 'TaxaAprovacao2011_6ano',
#        'TaxaAprovacao2011_7ano', 'TaxaAprovacao2011_8ano',
#        'TaxaAprovacao2011_9ano', 'IndicadorRendimento_2011',
#        'TaxaAprovacao2013_6ao9ano', 'TaxaAprovacao2013_6ano',
#        'TaxaAprovacao2013_7ano', 'TaxaAprovacao2013_8ano',
#        'TaxaAprovacao2013_9ano', 'IndicadorRendimento_2013',
#        'TaxaAprovacao2015_6ao9ano', 'TaxaAprovacao2015_6ano',
#        'TaxaAprovacao2015_7ano', 'TaxaAprovacao2015_8ano',
#        'TaxaAprovacao2015_9ano', 'IndicadorRendimento_2015',
#        'TaxaAprovacao2017_6ao9ano', 'TaxaAprovacao2017_6ano',
#        'TaxaAprovacao2017_7ano', 'TaxaAprovacao2017_8ano',
#        'TaxaAprovacao2017_9ano', 'IndicadorRendimento_2017',
#        'NotaProvaBrasil_MT_2005', 'NotaProvaBrasil_LP_2005',
#        'NotaProvaBrasil_NotaMedia_2005', 'NotaProvaBrasil_MT_2007',
#        'NotaProvaBrasil_LP_2007', 'NotaProvaBrasil_NotaMedia_2007',
#        'NotaProvaBrasil_MT_2009', 'NotaProvaBrasil_LP_2009',
#        'NotaProvaBrasil_NotaMedia_2009', 'NotaProvaBrasil_MT_2011',
#        'NotaProvaBrasil_LP_2011', 'NotaProvaBrasil_NotaMedia_2011',
#        'NotaProvaBrasil_MT_2013', 'NotaProvaBrasil_LP_2013',
#        'NotaProvaBrasil_NotaMedia_2013', 'NotaProvaBrasil_MT_2015',
#        'NotaProvaBrasil_LP_2015', 'NotaProvaBrasil_NotaMedia_2015',
#        'NotaProvaBrasil_MT_2017', 'NotaProvaBrasil_LP_2017',
#        'NotaProvaBrasil_NotaMedia_2017', 'Ideb2005', 'Ideb2007', 'Ideb2009',
#        'Ideb2011', 'Ideb2013', 'Ideb2015', 'Ideb2017', 'ProjecaoIdeb2007',
#        'ProjecaoIdeb2009', 'ProjecaoIdeb2011', 'ProjecaoIdeb2013',
#        'ProjecaoIdeb2015', 'ProjecaoIdeb2017', 'ProjecaoIdeb2019',
#        'ProjecaoIdeb2021'],
#       dtype='object')

# %%
df_ideb_ini[['Cod_Municipio_Completo', 'Ideb2017']].head()
# Out:
#    Cod_Municipio_Completo Ideb2017
# 0               1100015.0      6.2
# 1               1100015.0      5.1
# 2               1100015.0      6.2
# 3               1100023.0        6
# 4               1100023.0      5.4

# %%
df_ideb_ini = df_ideb_ini.rename(columns={'Cod_Municipio_Completo': 'cod_municipio'})
df_ideb_fin = df_ideb_fin.rename(columns={'Cod_Municipio_Completo': 'cod_municipio'})

df_ideb_ini_2015 = df_ideb_ini.copy()
df_ideb_ini_2017 = df_ideb_ini.copy()

df_ideb_fin_2015 = df_ideb_fin.copy()
df_ideb_fin_2017 = df_ideb_fin.copy()

# %%
df_ideb_ini_2015 = df_ideb_ini_2015[['cod_municipio', 'Ideb2015']]
df_ideb_ini_2017 = df_ideb_ini_2017[['cod_municipio', 'Ideb2017']]

df_ideb_fin_2015 = df_ideb_fin_2015[['cod_municipio', 'Ideb2015']]
df_ideb_fin_2017 = df_ideb_fin_2017[['cod_municipio', 'Ideb2017']]

# %%
df_ideb_ini_2015.head()
# Out:
#    cod_municipio Ideb2015
# 0      1100015.0      5.8
# 1      1100015.0        5
# 2      1100015.0      5.8
# 3      1100023.0      5.6
# 4      1100023.0        5

# %%
df_ideb_ini_2017.head()
# Out:
#    cod_municipio Ideb2017
# 0      1100015.0      6.2
# 1      1100015.0      5.1
# 2      1100015.0      6.2
# 3      1100023.0        6
# 4      1100023.0      5.4

# %%
df_ideb_fin_2015.head()
# Out:
#    cod_municipio Ideb2015
# 0      1100015.0      4.2
# 1      1100015.0        -
# 2      1100015.0      4.3
# 3      1100023.0      4.3
# 4      1100023.0      4.6

# %%
df_ideb_fin_2017.head()
# Out:
#    cod_municipio Ideb2017
# 0      1100015.0      5.1
# 1      1100015.0      4.3
# 2      1100015.0      4.8
# 3      1100023.0        5
# 4      1100023.0      4.7

# %%
df_ideb_ini_2015['cod_municipio'] = df_ideb_ini_2015.cod_municipio.astype(float)
df_ideb_ini_2017['cod_municipio'] = df_ideb_ini_2017.cod_municipio.astype(float)

df_ideb_fin_2015['cod_municipio'] = df_ideb_fin_2015.cod_municipio.astype(float)
df_ideb_fin_2017['cod_municipio'] = df_ideb_fin_2017.cod_municipio.astype(float)

# %%
df_result_ini_2015 = pd.merge(df_municipios_2015, df_ideb_ini_2015, how='inner', on='cod_municipio')
df_result_ini_2017 = pd.merge(df_municipios_2017, df_ideb_ini_2017, how='inner', on='cod_municipio')

df_result_fin_2015 = pd.merge(df_municipios_2015, df_ideb_fin_2015, how='inner', on='cod_municipio')
df_result_fin_2017 = pd.merge(df_municipios_2017, df_ideb_fin_2017, how='inner', on='cod_municipio')

# %%
df_result_ini_2015 = df_result_ini_2015.rename(columns={'Ideb2015': 'ideb'})
df_result_ini_2017 = df_result_ini_2017.rename(columns={'Ideb2017': 'ideb'})

df_result_fin_2015 = df_result_fin_2015.rename(columns={'Ideb2015': 'ideb'})
df_result_fin_2017 = df_result_fin_2017.rename(columns={'Ideb2017': 'ideb'})

# %%
df_result_ini_2015.sort_values(by=['ideb'], ascending=False).head(8)
# Out:
#       ano_censo    regiao unidade_federativa         mesoregiao  \
# 6948       2015  Nordeste              Ceará  Noroeste Cearense
# 6947       2015  Nordeste              Ceará  Noroeste Cearense
# 6935       2015  Nordeste              Ceará  Noroeste Cearense
# 6936       2015  Nordeste              Ceará  Noroeste Cearense
# 2280       2015   Sudeste       Minas Gerais      Jequitinhonha
# 7995       2015  Nordeste              Ceará  Sertões Cearenses
# 7994       2015  Nordeste              Ceará  Sertões Cearenses
# 6056       2015     Norte           Amazonas  Centro Amazonense
#
#                    microregiao                  municipio  cod_municipio  \
# 6948                    Sobral                     Sobral        2312908
# 6947                    Sobral                     Sobral        2312908
# 6935                       Ipu             Pires Ferreira        2310951
# 6936                       Ipu             Pires Ferreira        2310951
# 2280                 Capelinha                 Aricanduva        3104452
# 7995  Sertão de Senador Pompeu  Deputado Irapuan Pinheiro        2304269
# 7994  Sertão de Senador Pompeu  Deputado Irapuan Pinheiro        2304269
# 6056                     Coari                     Beruri        1300631
#
#       num_escolas  num_escolas_em_atividade  num_estudantes_ensino_infantil  \
# 6948          264                       107                           10236
# 6947          264                       107                           10236
# 6935           32                        19                             354
# 6936           32                        19                             354
# 2280           22                         7                             155
# 7995           20                        10                             327
# 7994           20                        10                             327
# 6056           88                        79                             531
#
#       num_estudantes_ensino_fund_anos_iniciais  \
# 6948                                     14984
# 6947                                     14984
# 6935                                       774
# 6936                                       774
# 2280                                       426
# 7995                                       611
# 7994                                       611
# 6056                                      3453
#
#       num_estudantes_ensino_fund_anos_finais  \
# 6948                                   13343
# 6947                                   13343
# 6935                                     753
# 6936                                     753
# 2280                                     523
# 7995                                     622
# 7994                                     622
# 6056                                    2104
#
#       num_estudantes_ensino_medio_propedeutico  num_estudantes_fund_1_ano  \
# 6948                                     10807                       2803
# 6947                                     10807                       2803
# 6935                                       393                        155
# 6936                                       393                        155
# 2280                                       238                         87
# 7995                                       391                        132
# 7994                                       391                        132
# 6056                                      1252                        488
#
#       num_estudantes_fund_2_ano  num_estudantes_fund_3_ano  \
# 6948                       2786                       3166
# 6947                       2786                       3166
# 6935                        145                        183
# 6936                        145                        183
# 2280                         88                         95
# 7995                        112                        116
# 7994                        112                        116
# 6056                        625                        856
#
#       num_estudantes_fund_4_ano  num_estudantes_fund_5_ano  \
# 6948                       3354                       2875
# 6947                       3354                       2875
# 6935                        185                        106
# 6936                        185                        106
# 2280                         75                         81
# 7995                        130                        121
# 7994                        130                        121
# 6056                        758                        743
#
#       num_estudantes_fund_6_ano  num_estudantes_fund_7_ano  \
# 6948                       3333                       3204
# 6947                       3333                       3204
# 6935                        173                        197
# 6936                        173                        197
# 2280                        121                        121
# 7995                        144                        155
# 7994                        144                        155
# 6056                        715                        518
#
#       num_estudantes_fund_8_ano  num_estudantes_fund_9_ano  \
# 6948                       3533                       3273
# 6947                       3533                       3273
# 6935                        189                        194
# 6936                        189                        194
# 2280                        165                        116
# 7995                        165                        158
# 7994                        165                        158
# 6056                        449                        422
#
#       num_estudantes_medio_1_serie  num_estudantes_medio_2_serie  \
# 6948                          4066                          3611
# 6947                          4066                          3611
# 6935                           157                           118
# 6936                           157                           118
# 2280                           107                            75
# 7995                           140                           142
# 7994                           140                           142
# 6056                           537                           437
#
#       num_estudantes_medio_3_serie  num_estudantes_medio_4_serie  \
# 6948                          3130                             0
# 6947                          3130                             0
# 6935                           118                             0
# 6936                           118                             0
# 2280                            56                             0
# 7995                           109                             0
# 7994                           109                             0
# 6056                           278                             0
#
#       num_estudantes_medio_nao_seriada  num_salas_existentes  \
# 6948                                 0                  1489
# 6947                                 0                  1489
# 6935                                 0                    81
# 6936                                 0                    81
# 2280                                 0                    46
# 7995                                 0                    50
# 7994                                 0                    50
# 6056                                 0                   170
#
#       num_salas_utilizadas  num_equip_tv  num_equip_videocassete  \
# 6948                  2516            99                      16
# 6947                  2516            99                      16
# 6935                    78            16                       4
# 6936                    78            16                       4
# 2280                    44             7                       3
# 7995                    80            10                       4
# 7994                    80            10                       4
# 6056                   206            10                       2
#
#       num_equip_dvd  num_equip_parabolica  num_equip_copiadora  \
# 6948             82                    39                   81
# 6947             82                    39                   81
# 6935             12                     4                   12
# 6936             12                     4                   12
# 2280              7                     2                    1
# 7995             10                     4                    6
# 7994             10                     4                    6
# 6056              4                     2                    1
#
#       num_equip_retroprojetor  num_equip_impressora  \
# 6948                       39                    94
# 6947                       39                    94
# 6935                        2                     7
# 6936                        2                     7
# 2280                        1                     3
# 7995                        9                    10
# 7994                        9                    10
# 6056                        2                    10
#
#       num_equip_impressora_mult  num_equip_som  num_equip_multimidia  \
# 6948                         27             95                    91
# 6947                         27             95                    91
# 6935                          3              9                     6
# 6936                          3              9                     6
# 2280                          0              2                     1
# 7995                          6             10                     9
# 7994                          6             10                     9
# 6056                          0              2                     4
#
#       num_equip_fax  num_equip_foto  num_computador  num_comp_administrativo  \
# 6948             34              77             106                      101
# 6947             34              77             106                      101
# 6935              0               4               9                        7
# 6936              0               4               9                        7
# 2280              0               1               7                        3
# 7995              1               9               9                        6
# 7994              1               9               9                        6
# 6056              2               3              11                        8
#
#       num_comp_aluno  num_funcionarios  num_escolas_rurais  \
# 6948              88              6366                   0
# 6947              88              6366                   0
# 6935               6               383                   0
# 6936               6               383                   0
# 2280               2               162                   0
# 7995               6               264                   0
# 7994               6               264                   0
# 6056              10               956                   0
#
#       num_escolas_urbanas  num_professores  num_matriculas  num_estudantes  \
# 6948                    0             2456           64615           59982
# 6947                    0             2456           64615           59982
# 6935                    0              173            3129            2592
# 6936                    0              173            3129            2592
# 2280                    0               76            1425            1374
# 7995                    0              154            2689            2176
# 7994                    0              154            2689            2176
# 6056                    0              462            8124            8087
#
#       num_turmas ideb
# 6948        2620  8.8
# 6947        2620  8.8
# 6935         172  8.7
# 6936         172  8.7
# 2280          73  8.3
# 7995         148  8.2
# 7994         148  8.2
# 6056         396  8.2

# %%
df_result_ini_2017.sort_values(by=['ideb'], ascending=False).head(8)
# Out:
#       ano_censo    regiao unidade_federativa             mesoregiao  \
# 6964       2017  Nordeste              Ceará      Noroeste Cearense
# 6965       2017  Nordeste              Ceará      Noroeste Cearense
# 5374       2017       Sul             Paraná       Oeste Paranaense
# 5375       2017       Sul             Paraná       Oeste Paranaense
# 7984       2017  Nordeste              Ceará      Sertões Cearenses
# 7985       2017  Nordeste              Ceará      Sertões Cearenses
# 2516       2017  Nordeste            Alagoas         Leste Alagoano
# 9834       2017   Sudeste       Minas Gerais  Sul/Sudoeste de Minas
#
#                    microregiao                  municipio  cod_municipio  \
# 6964                    Sobral                     Sobral        2312908
# 6965                    Sobral                     Sobral        2312908
# 5374             Foz do Iguaçu     Serranópolis do Iguaçu        4126355
# 5375             Foz do Iguaçu     Serranópolis do Iguaçu        4126355
# 7984  Sertão de Senador Pompeu  Deputado Irapuan Pinheiro        2304269
# 7985  Sertão de Senador Pompeu  Deputado Irapuan Pinheiro        2304269
# 2516     São Miguel dos Campos                   Coruripe        2702306
# 9834                    Passos          São José da Barra        3162948
#
#       num_escolas  num_escolas_em_atividade  num_estudantes_ensino_infantil  \
# 6964          267                       108                           11329
# 6965          267                       108                           11329
# 5374            6                         4                             201
# 5375            6                         4                             201
# 7984           20                        10                             305
# 7985           20                        10                             305
# 2516           48                        30                            3618
# 9834           19                         7                             190
#
#       num_estudantes_ensino_fund_anos_iniciais  \
# 6964                                     14463
# 6965                                     14463
# 5374                                       312
# 5375                                       312
# 7984                                       601
# 7985                                       601
# 2516                                      4907
# 9834                                       516
#
#       num_estudantes_ensino_fund_anos_finais  \
# 6964                                   12637
# 6965                                   12637
# 5374                                     279
# 5375                                     279
# 7984                                     536
# 7985                                     536
# 2516                                    3930
# 9834                                     376
#
#       num_estudantes_ensino_medio_propedeutico  num_estudantes_fund_1_ano  \
# 6964                                     10393                       2855
# 6965                                     10393                       2855
# 5374                                       108                         65
# 5375                                       108                         65
# 7984                                       406                        118
# 7985                                       406                        118
# 2516                                      2594                        950
# 9834                                       249                        104
#
#       num_estudantes_fund_2_ano  num_estudantes_fund_3_ano  \
# 6964                       2824                       2814
# 6965                       2824                       2814
# 5374                         58                         50
# 5375                         58                         50
# 7984                        128                        128
# 7985                        128                        128
# 2516                        910                        975
# 9834                         94                         96
#
#       num_estudantes_fund_4_ano  num_estudantes_fund_5_ano  \
# 6964                       3104                       2866
# 6965                       3104                       2866
# 5374                         66                         73
# 5375                         66                         73
# 7984                        116                        111
# 7985                        116                        111
# 2516                       1068                       1004
# 9834                        135                         87
#
#       num_estudantes_fund_6_ano  num_estudantes_fund_7_ano  \
# 6964                       3336                       3095
# 6965                       3336                       3095
# 5374                         66                         70
# 5375                         66                         70
# 7984                        139                        126
# 7985                        139                        126
# 2516                       1152                       1011
# 9834                         80                        116
#
#       num_estudantes_fund_8_ano  num_estudantes_fund_9_ano  \
# 6964                       3337                       2869
# 6965                       3337                       2869
# 5374                         61                         82
# 5375                         61                         82
# 7984                        125                        146
# 7985                        125                        146
# 2516                        998                        769
# 9834                         97                         83
#
#       num_estudantes_medio_1_serie  num_estudantes_medio_2_serie  \
# 6964                          3230                          3078
# 6965                          3230                          3078
# 5374                            46                            25
# 5375                            46                            25
# 7984                           163                           129
# 7985                           163                           129
# 2516                          1104                           738
# 9834                            89                            96
#
#       num_estudantes_medio_3_serie  num_estudantes_medio_4_serie  \
# 6964                          2954                             0
# 6965                          2954                             0
# 5374                            37                             0
# 5375                            37                             0
# 7984                           114                             0
# 7985                           114                             0
# 2516                           558                             0
# 9834                            64                             0
#
#       num_estudantes_medio_nao_seriada  num_salas_existentes  \
# 6964                                 0                  1558
# 6965                                 0                  1558
# 5374                                 0                    43
# 5375                                 0                    43
# 7984                                 0                    52
# 7985                                 0                    52
# 2516                                 0                   382
# 9834                                 0                    70
#
#       num_salas_utilizadas  num_equip_tv  num_equip_videocassete  \
# 6964                  1405           249                      17
# 6965                  1405           249                      17
# 5374                    39            22                       0
# 5375                    39            22                       0
# 7984                    66            22                       2
# 7985                    66            22                       2
# 2516                   371            45                       8
# 9834                    53            11                       5
#
#       num_equip_dvd  num_equip_parabolica  num_equip_copiadora  \
# 6964            164                    41                  128
# 6965            164                    41                  128
# 5374              6                     3                    3
# 5375              6                     3                    3
# 7984             17                     4                    5
# 7985             17                     4                    5
# 2516             37                    14                   21
# 9834             10                     3                   11
#
#       num_equip_retroprojetor  num_equip_impressora  \
# 6964                       93                   244
# 6965                       93                   244
# 5374                        2                    12
# 5375                        2                    12
# 7984                        9                    10
# 7985                        9                    10
# 2516                       15                    51
# 9834                        6                    20
#
#       num_equip_impressora_mult  num_equip_som  num_equip_multimidia  \
# 6964                         89            233                   320
# 6965                         89            233                   320
# 5374                          3             35                    23
# 5375                          3             35                    23
# 7984                         17             25                    16
# 7985                         17             25                    16
# 2516                         15             42                    44
# 9834                          1              8                     8
#
#       num_equip_fax  num_equip_foto  num_computador  num_comp_administrativo  \
# 6964             21              88            2229                      656
# 6965             21              88            2229                      656
# 5374              1              10              98                       37
# 5375              1              10              98                       37
# 7984              0              16             101                       26
# 7985              0              16             101                       26
# 2516              3              16             373                       84
# 9834              5               7             130                       27
#
#       num_comp_aluno  num_funcionarios  num_escolas_rurais  \
# 6964            1528              6406                   0
# 6965            1528              6406                   0
# 5374              61               147                   0
# 5375              61               147                   0
# 7984              78               259                   0
# 7985              78               259                   0
# 2516             264              1670                   0
# 9834             103               247                   0
#
#       num_escolas_urbanas  num_professores  num_matriculas  num_estudantes  \
# 6964                    0             2526           65080           57805
# 6965                    0             2526           65080           57805
# 5374                    0               75            1156             904
# 5375                    0               75            1156             904
# 7984                    0              154            2521            2020
# 7985                    0              154            2521            2020
# 2516                    0              916           19159           17306
# 9834                    0               98            1502            1427
#
#       num_turmas ideb
# 6964        2669  9.1
# 6965        2669  9.1
# 5374          73  8.7
# 5375          73  8.7
# 7984         141  8.6
# 7985         141  8.6
# 2516         787  8.5
# 9834          74  8.5

# %%
df_result_fin_2015.sort_values(by=['ideb'], ascending=False).head(8)
# Out:
#        ano_censo        regiao  unidade_federativa  \
# 12173       2015           Sul              Paraná
# 12266       2015      Nordeste               Bahia
# 11560       2015      Nordeste          Pernambuco
# 13518       2015           Sul   Rio Grande do Sul
# 12662       2015      Nordeste               Ceará
# 4723        2015  Centro-Oeste    Distrito Federal
# 14188       2015  Centro-Oeste  Mato Grosso do Sul
# 14203       2015       Sudeste        Minas Gerais
#
#                                mesoregiao   microregiao     municipio  \
# 12173           Metropolitana de Curitiba      Curitiba      Curitiba
# 12266           Metropolitana de Salvador      Salvador      Salvador
# 11560             Metropolitana de Recife        Recife        Recife
# 13518      Centro Ocidental Rio-grandense   Santa Maria   Santa Maria
# 12662          Metropolitana de Fortaleza     Fortaleza     Fortaleza
# 4723                     Distrito Federal      Brasília      Brasília
# 14188  Centro Norte de Mato Grosso do Sul  Campo Grande  Campo Grande
# 14203    Triângulo Mineiro/Alto Paranaíba         Araxá    Nova Ponte
#
#        cod_municipio  num_escolas  num_escolas_em_atividade  \
# 12173        4106902         1263                      1056
# 12266        2927408         1393                      1325
# 11560        2611606         1598                      1035
# 13518        4316907          206                       177
# 12662        2304400         2203                      1303
# 4723         5300108         1386                      1200
# 14188        5002704          557                       461
# 14203        3145000           17                         9
#
#        num_estudantes_ensino_infantil  \
# 12173                           68183
# 12266                           53919
# 11560                           47858
# 13518                            8636
# 12662                           94366
# 4723                            89765
# 14188                           36175
# 14203                             556
#
#        num_estudantes_ensino_fund_anos_iniciais  \
# 12173                                    122641
# 12266                                    133544
# 11560                                     96423
# 13518                                     17257
# 12662                                    174663
# 4723                                     209710
# 14188                                     64280
# 14203                                      1112
#
#        num_estudantes_ensino_fund_anos_finais  \
# 12173                                  101865
# 12266                                  137285
# 11560                                   88839
# 13518                                   13147
# 12662                                  140855
# 4723                                   181902
# 14188                                   54080
# 14203                                     998
#
#        num_estudantes_ensino_medio_propedeutico  num_estudantes_fund_1_ano  \
# 12173                                     69385                      25908
# 12266                                     88070                      23002
# 11560                                     63284                      17991
# 13518                                      9097                       3160
# 12662                                     92075                      33553
# 4723                                     109394                      41162
# 14188                                     31021                      12615
# 14203                                       490                        224
#
#        num_estudantes_fund_2_ano  num_estudantes_fund_3_ano  \
# 12173                      24464                      25676
# 12266                      23953                      31438
# 11560                      18510                      20969
# 13518                       3027                       3583
# 12662                      33169                      36229
# 4723                       39126                      44624
# 14188                      14740                      12172
# 14203                        229                        244
#
#        num_estudantes_fund_4_ano  num_estudantes_fund_5_ano  \
# 12173                      23257                      23336
# 12266                      26243                      28909
# 11560                      19756                      19197
# 13518                       3708                       3779
# 12662                      35701                      36012
# 4723                       41381                      43430
# 14188                      11558                      13195
# 14203                        228                        187
#
#        num_estudantes_fund_6_ano  num_estudantes_fund_7_ano  \
# 12173                      26676                      25303
# 12266                      40361                      35280
# 11560                      23196                      22720
# 13518                       4137                       3691
# 12662                      39002                      35542
# 4723                       51577                      46533
# 14188                      14234                      14044
# 14203                        205                        222
#
#        num_estudantes_fund_8_ano  num_estudantes_fund_9_ano  \
# 12173                      25527                      24359
# 12266                      31451                      30199
# 11560                      22170                      20753
# 13518                       3141                       2178
# 12662                      34344                      31980
# 4723                       42800                      41010
# 14188                      14165                      11637
# 14203                        295                        276
#
#        num_estudantes_medio_1_serie  num_estudantes_medio_2_serie  \
# 12173                         26609                         22965
# 12266                         35594                         27750
# 11560                         24138                         20887
# 13518                          4070                          2785
# 12662                         35621                         29931
# 4723                          44673                         35770
# 14188                         12177                         10586
# 14203                           221                           141
#
#        num_estudantes_medio_3_serie  num_estudantes_medio_4_serie  \
# 12173                         19789                            22
# 12266                         24726                             0
# 11560                         18011                             0
# 13518                          2242                             0
# 12662                         26506                             0
# 4723                          28951                             0
# 14188                          8258                             0
# 14203                           128                             0
#
#        num_estudantes_medio_nao_seriada  num_salas_existentes  \
# 12173                                 0                 14351
# 12266                                 0                 14726
# 11560                               248                 12063
# 13518                                 0                  1987
# 12662                                17                 18238
# 4723                                 14                 20351
# 14188                                 0                  5876
# 14203                                 0                   107
#
#        num_salas_utilizadas  num_equip_tv  num_equip_videocassete  \
# 12173                 13009          1010                     372
# 12266                 13235          1242                     316
# 11560                 11441           939                     163
# 13518                  1764           175                      77
# 12662                 17956          1223                     267
# 4723                  18754          1151                     610
# 14188                  5419           448                     167
# 14203                    89             9                       2
#
#        num_equip_dvd  num_equip_parabolica  num_equip_copiadora  \
# 12173            965                   246                  621
# 12266           1153                   283                  893
# 11560            848                   126                  718
# 13518            166                    33                  121
# 12662           1122                   169                 1048
# 4723            1111                   469                 1057
# 14188            428                   106                  297
# 14203              9                     5                    7
#
#        num_equip_retroprojetor  num_equip_impressora  \
# 12173                      566                   956
# 12266                      554                  1127
# 11560                      335                   838
# 13518                       96                   157
# 12662                      511                  1097
# 4723                       794                  1122
# 14188                      238                   408
# 14203                        3                     9
#
#        num_equip_impressora_mult  num_equip_som  num_equip_multimidia  \
# 12173                        288            972                   810
# 12266                        535           1153                   678
# 11560                        240            875                   611
# 13518                         94            169                   149
# 12662                        533           1146                   878
# 4723                         442           1109                   981
# 14188                        187            423                   328
# 14203                          5              8                     8
#
#        num_equip_fax  num_equip_foto  num_computador  num_comp_administrativo  \
# 12173            662             896            1053                      943
# 12266            459             771            1289                     1068
# 11560            208             674             987                      720
# 13518             44             155             173                      158
# 12662            475             982            1285                     1067
# 4723             538             849            1191                      928
# 14188            189             352             457                      393
# 14203              1               7               9                        9
#
#        num_comp_aluno  num_funcionarios  num_escolas_rurais  \
# 12173             779             56953                   0
# 12266             760             60593                   0
# 11560             720             44928                   0
# 13518             133              7445                   0
# 12662             853             60305                   0
# 4723              835             82921                   0
# 14188             279             27820                   0
# 14203               4               369                   0
#
#        num_escolas_urbanas  num_professores  num_matriculas  num_estudantes  \
# 12173                    0            26112          452313          418811
# 12266                    0            22754          568214          509094
# 11560                    0            16302          383907          360694
# 13518                    0             3522           63230           57656
# 12662                    0            24751          635194          577153
# 4723                     0            35239          747036          664926
# 14188                    0            12180          236784          210908
# 14203                    0              176            3362            3245
#
#        num_turmas ideb
# 12173       19654  7.7
# 12266       23659  7.5
# 11560       16867  7.4
# 13518        3498  7.3
# 12662       27969  7.2
# 4723        34039  7.2
# 14188       10380  7.1
# 14203         146    7

# %%
df_result_fin_2017.sort_values(by=['ideb'], ascending=False).head(8)
# Out:
#        ano_censo        regiao  unidade_federativa  \
# 12260       2017      Nordeste               Bahia
# 11554       2017      Nordeste          Pernambuco
# 12172       2017           Sul              Paraná
# 13889       2017       Sudeste        Minas Gerais
# 5094        2017         Norte             Roraima
# 13544       2017           Sul   Rio Grande do Sul
# 14177       2017  Centro-Oeste  Mato Grosso do Sul
# 4723        2017  Centro-Oeste    Distrito Federal
#
#                                mesoregiao     microregiao       municipio  \
# 12260           Metropolitana de Salvador        Salvador        Salvador
# 11554             Metropolitana de Recife          Recife          Recife
# 12172           Metropolitana de Curitiba        Curitiba        Curitiba
# 13889     Metropolitana de Belo Horizonte  Belo Horizonte  Belo Horizonte
# 5094                     Norte de Roraima       Boa Vista       Boa Vista
# 13544      Centro Ocidental Rio-grandense     Santa Maria     Santa Maria
# 14177  Centro Norte de Mato Grosso do Sul    Campo Grande    Campo Grande
# 4723                     Distrito Federal        Brasília        Brasília
#
#        cod_municipio  num_escolas  num_escolas_em_atividade  \
# 12260        2927408         1647                      1467
# 11554        2611606         1809                      1040
# 12172        4106902         1313                      1061
# 13889        3106200         2199                      1346
# 5094         1400100          287                       238
# 13544        4316907          208                       174
# 14177        5002704          580                       462
# 4723         5300108         1450                      1225
#
#        num_estudantes_ensino_infantil  \
# 12260                           65574
# 11554                           50084
# 12172                           69812
# 13889                           95877
# 5094                            14811
# 13544                            9999
# 14177                           39152
# 4723                            97217
#
#        num_estudantes_ensino_fund_anos_iniciais  \
# 12260                                    143295
# 11554                                    100653
# 12172                                    121709
# 13889                                    153486
# 5094                                      30483
# 13544                                     17018
# 14177                                     65754
# 4723                                     206756
#
#        num_estudantes_ensino_fund_anos_finais  \
# 12260                                  137358
# 11554                                   84755
# 12172                                   98832
# 13889                                  122776
# 5094                                    23921
# 13544                                   13966
# 14177                                   51277
# 4723                                   174632
#
#        num_estudantes_ensino_medio_propedeutico  num_estudantes_fund_1_ano  \
# 12260                                     93990                      25582
# 11554                                     66491                      19629
# 12172                                     75565                      25213
# 13889                                     98551                      29832
# 5094                                      15249                       5835
# 13544                                      8243                       3223
# 14177                                     33491                      12560
# 4723                                     109143                      40282
#
#        num_estudantes_fund_2_ano  num_estudantes_fund_3_ano  \
# 12260                      26874                      32303
# 11554                      19484                      21152
# 12172                      23778                      25390
# 13889                      29589                      31296
# 5094                        5631                       5910
# 13544                       3207                       3658
# 14177                      13973                      13439
# 4723                       39389                      45488
#
#        num_estudantes_fund_4_ano  num_estudantes_fund_5_ano  \
# 12260                      28607                      29930
# 11554                      20506                      19882
# 12172                      23580                      23748
# 13889                      32871                      29898
# 5094                        4901                       8206
# 13544                       3432                       3498
# 14177                      14096                      11686
# 4723                       40274                      41324
#
#        num_estudantes_fund_6_ano  num_estudantes_fund_7_ano  \
# 12260                      40255                      36419
# 11554                      21935                      21210
# 12172                      25403                      25012
# 13889                      30999                      30118
# 5094                        6233                       5924
# 13544                       4053                       3715
# 14177                      12320                      13715
# 4723                       47415                      45526
#
#        num_estudantes_fund_8_ano  num_estudantes_fund_9_ano  \
# 12260                      31256                      29428
# 11554                      20590                      21020
# 12172                      24815                      23602
# 13889                      30747                      30912
# 5094                        5869                       5895
# 13544                       3384                       2814
# 14177                      12829                      12413
# 4723                       41983                      39716
#
#        num_estudantes_medio_1_serie  num_estudantes_medio_2_serie  \
# 12260                         34530                         27711
# 11554                         21842                         19486
# 12172                         24513                         21008
# 13889                         40151                         29753
# 5094                           5621                          4202
# 13544                          3364                          2047
# 14177                         14366                          9545
# 4723                          43515                         34410
#
#        num_estudantes_medio_3_serie  num_estudantes_medio_4_serie  \
# 12260                         23873                             0
# 11554                         17419                             0
# 12172                         20913                            23
# 13889                         23846                             0
# 5094                           3782                             0
# 13544                          2202                             0
# 14177                          7077                             0
# 4723                          29371                             0
#
#        num_estudantes_medio_nao_seriada  num_salas_existentes  \
# 12260                                47                 16150
# 11554                              3529                 11544
# 12172                                26                 14463
# 13889                                 0                 16832
# 5094                                  0                  2623
# 13544                                 0                  1961
# 14177                               554                  5772
# 4723                                  0                 22483
#
#        num_salas_utilizadas  num_equip_tv  num_equip_videocassete  \
# 12260                 14419          6078                     474
# 11554                 10593          2428                     155
# 12172                 12907          7112                     360
# 13889                 15027          3314                     520
# 5094                   2353           687                      30
# 13544                  1803           641                      66
# 14177                  5332          1517                     147
# 4723                  18976          5299                     649
#
#        num_equip_dvd  num_equip_parabolica  num_equip_copiadora  \
# 12260           2903                   299                 1610
# 11554           1564                   127                  954
# 12172           2346                   211                  963
# 13889           2222                   345                 1577
# 5094             403                    21                  192
# 13544            387                    31                  169
# 14177            976                   103                  573
# 4723            3394                   453                 1855
#
#        num_equip_retroprojetor  num_equip_impressora  \
# 12260                     1067                  3228
# 11554                      478                  1610
# 12172                      724                  3158
# 13889                      824                  2869
# 5094                        65                   531
# 13544                       98                   500
# 14177                      274                  1050
# 4723                      1234                  3877
#
#        num_equip_impressora_mult  num_equip_som  num_equip_multimidia  \
# 12260                       1813           3768                  2629
# 11554                       1042           2452                  2812
# 12172                        914           5255                  3317
# 13889                       1182           3525                  2870
# 5094                         296            416                   430
# 13544                        301            646                   544
# 14177                        629           1440                  1242
# 4723                        1729           4573                  4433
#
#        num_equip_fax  num_equip_foto  num_computador  num_comp_administrativo  \
# 12260            518            1266           20834                     8402
# 11554            169             923           14358                     4742
# 12172            553            1701           27380                     8329
# 13889            751            1494           26802                    10085
# 5094              35             174            3763                     1184
# 13544             33             270            4783                     1358
# 14177            136             545           10011                     2850
# 4723             488            1267           33009                    10465
#
#        num_comp_aluno  num_funcionarios  num_escolas_rurais  \
# 12260           10814             63696                   0
# 11554            9162             42564                   0
# 12172           16386             56576                   0
# 13889           15746             64506                   0
# 5094             2540             12930                   0
# 13544            3388              7499                   0
# 14177            6700             27203                   0
# 4723            20507             82856                   0
#
#        num_escolas_urbanas  num_professores  num_matriculas  num_estudantes  \
# 12260                    0            24080          569539          527040
# 11554                    0            16020          396117          362491
# 12172                    0            24826          448652          426815
# 13889                    0            31029          589099          525681
# 5094                     0             4209           98146           94419
# 13544                    0             3600           63575           57232
# 14177                    0            12538          234241          208850
# 4723                     0            34892          733800          658816
#
#        num_turmas ideb
# 12260       25074  7.9
# 11554       17309  7.8
# 12172       18414  7.7
# 13889       26294  7.7
# 5094         4231  7.5
# 13544        3690  7.5
# 14177       10716  7.4
# 4723        34176  7.3

# %% [markdown]
# ## Limpeza do Ideb

# %%
df_result_ini_2015.drop(df_result_ini_2015[df_result_ini_2015.ideb == '-'].index, inplace=True)
df_result_ini_2017.drop(df_result_ini_2017[df_result_ini_2017.ideb == '-'].index, inplace=True)
df_result_fin_2015.drop(df_result_fin_2015[df_result_fin_2015.ideb == '-'].index, inplace=True)
df_result_fin_2017.drop(df_result_fin_2017[df_result_fin_2017.ideb == '-'].index, inplace=True)

# %%
df_result_ini_2015['ideb'] = pd.to_numeric(df_result_ini_2015['ideb'])
df_result_ini_2017['ideb'] = pd.to_numeric(df_result_ini_2017['ideb'])

df_result_fin_2015['ideb'] = pd.to_numeric(df_result_fin_2015['ideb'])
df_result_fin_2017['ideb'] = pd.to_numeric(df_result_fin_2017['ideb'])

# %%
print(df_result_ini_2015.shape)
print(df_result_fin_2015.shape)
print(df_result_ini_2017.shape)
print(df_result_fin_2017.shape)
# Out:
# (12048, 52)
# (12158, 52)
# (12508, 52)
# (12751, 52)

# %% [markdown]
# # Correlação linear entre todas as variáveis numéricas com o Ideb

# %%
def calculate_pearson(df):
    correlations = {}
    numerical_features = df.select_dtypes(exclude = ["object"]).columns
    numerical_features = numerical_features.drop("cod_municipio")
    for i in numerical_features:
        corr = stats.pearsonr(df[i], df['ideb'])[0]
        correlations[i] = corr
    df_corr = pd.DataFrame(list(correlations.items()), columns=['feature', 'correlation_with_ideb'])        
    df_corr = df_corr.dropna()
    
    return df_corr

# %%
df_corr_ini_2015 = calculate_pearson(df_result_ini_2015)
df_corr_ini_2017 = calculate_pearson(df_result_ini_2017)

df_corr_fin_2015 = calculate_pearson(df_result_fin_2015)
df_corr_fin_2017 = calculate_pearson(df_result_fin_2017)
# Out:
# /home/alexandre_silva/.virtualenvs/E-xray-lPsyvFV7/lib/python3.5/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
df_corr_ini_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
#                                      feature  correlation_with_ideb
# 33                                      ideb               1.000000
# 3                     num_equip_videocassete               0.049761
# 10                             num_equip_fax               0.049432
# 38                 num_equip_impressora_mult               0.048862
# 19                   num_equip_retroprojetor               0.047042
# 18                            num_equip_foto               0.042021
# 24                   num_comp_administrativo               0.040160
# 16                      num_equip_multimidia               0.039532
# 21                      num_equip_parabolica               0.039040
# 39                            num_comp_aluno               0.038141
# 14            num_estudantes_ensino_infantil               0.036071
# 4               num_estudantes_medio_3_serie               0.034474
# 42              num_estudantes_medio_2_serie               0.033280
# 32                       num_equip_copiadora               0.032512
# 34                             num_equip_som               0.031863
# 25  num_estudantes_ensino_medio_propedeutico               0.031815
# 1                       num_salas_existentes               0.031312
# 5                            num_professores               0.031203
# 43                      num_salas_utilizadas               0.030932
# 9                           num_funcionarios               0.030136
# 22                      num_equip_impressora               0.029948
# 12                 num_estudantes_fund_9_ano               0.029919
# 15              num_estudantes_medio_1_serie               0.029034
# 2                             num_computador               0.026825
# 26                 num_estudantes_fund_8_ano               0.026225
# 36                            num_estudantes               0.023313
# 30                             num_equip_dvd               0.023169
# 13                                num_turmas               0.022823
# 28                 num_estudantes_fund_2_ano               0.022479
# 23                 num_estudantes_fund_1_ano               0.022232
# 37    num_estudantes_ensino_fund_anos_finais               0.021479
# 20                              num_equip_tv               0.021455
# 11                            num_matriculas               0.021332
# 35                 num_estudantes_fund_7_ano               0.017068
# 27  num_estudantes_ensino_fund_anos_iniciais               0.015692
# 29                 num_estudantes_fund_3_ano               0.012040
# 6                  num_estudantes_fund_5_ano               0.011385
# 8                  num_estudantes_fund_6_ano               0.011223
# 40                 num_estudantes_fund_4_ano               0.010597
# 44          num_estudantes_medio_nao_seriada              -0.002350
# 41                  num_escolas_em_atividade              -0.007378
# 31              num_estudantes_medio_4_serie              -0.008793
# 45                               num_escolas              -0.011799

# %%
df_corr_ini_2017.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
#                                      feature  correlation_with_ideb
# 33                                      ideb               1.000000
# 39                            num_comp_aluno               0.055455
# 34                             num_equip_som               0.054287
# 2                             num_computador               0.052223
# 24                   num_comp_administrativo               0.050169
# 38                 num_equip_impressora_mult               0.049948
# 3                     num_equip_videocassete               0.048823
# 22                      num_equip_impressora               0.048606
# 19                   num_equip_retroprojetor               0.046856
# 16                      num_equip_multimidia               0.046426
# 20                              num_equip_tv               0.045649
# 30                             num_equip_dvd               0.045494
# 10                             num_equip_fax               0.045256
# 18                            num_equip_foto               0.044231
# 21                      num_equip_parabolica               0.041143
# 32                       num_equip_copiadora               0.037092
# 14            num_estudantes_ensino_infantil               0.035981
# 4               num_estudantes_medio_3_serie               0.034376
# 42              num_estudantes_medio_2_serie               0.033271
# 12                 num_estudantes_fund_9_ano               0.032726
# 5                            num_professores               0.032524
# 25  num_estudantes_ensino_medio_propedeutico               0.032346
# 1                       num_salas_existentes               0.032105
# 43                      num_salas_utilizadas               0.031459
# 9                           num_funcionarios               0.030486
# 15              num_estudantes_medio_1_serie               0.029982
# 26                 num_estudantes_fund_8_ano               0.027263
# 36                            num_estudantes               0.025054
# 13                                num_turmas               0.024761
# 11                            num_matriculas               0.024283
# 23                 num_estudantes_fund_1_ano               0.024282
# 28                 num_estudantes_fund_2_ano               0.023272
# 37    num_estudantes_ensino_fund_anos_finais               0.022111
# 27  num_estudantes_ensino_fund_anos_iniciais               0.018917
# 35                 num_estudantes_fund_7_ano               0.018888
# 40                 num_estudantes_fund_4_ano               0.017115
# 6                  num_estudantes_fund_5_ano               0.015559
# 29                 num_estudantes_fund_3_ano               0.014613
# 8                  num_estudantes_fund_6_ano               0.012618
# 31              num_estudantes_medio_4_serie              -0.003151
# 41                  num_escolas_em_atividade              -0.006031
# 45                               num_escolas              -0.012938
# 44          num_estudantes_medio_nao_seriada              -0.025696

# %%
df_corr_fin_2015.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
#                                      feature  correlation_with_ideb
# 33                                      ideb               1.000000
# 3                     num_equip_videocassete               0.045180
# 10                             num_equip_fax               0.044322
# 19                   num_equip_retroprojetor               0.043963
# 38                 num_equip_impressora_mult               0.042863
# 16                      num_equip_multimidia               0.039565
# 18                            num_equip_foto               0.039189
# 24                   num_comp_administrativo               0.038654
# 39                            num_comp_aluno               0.038337
# 21                      num_equip_parabolica               0.037535
# 4               num_estudantes_medio_3_serie               0.037510
# 42              num_estudantes_medio_2_serie               0.035202
# 14            num_estudantes_ensino_infantil               0.034410
# 32                       num_equip_copiadora               0.033313
# 25  num_estudantes_ensino_medio_propedeutico               0.033276
# 5                            num_professores               0.032698
# 9                           num_funcionarios               0.032396
# 1                       num_salas_existentes               0.032394
# 43                      num_salas_utilizadas               0.032043
# 12                 num_estudantes_fund_9_ano               0.030437
# 15              num_estudantes_medio_1_serie               0.029067
# 22                      num_equip_impressora               0.028760
# 34                             num_equip_som               0.028101
# 26                 num_estudantes_fund_8_ano               0.027877
# 2                             num_computador               0.026343
# 36                            num_estudantes               0.025464
# 13                                num_turmas               0.024910
# 28                 num_estudantes_fund_2_ano               0.024689
# 37    num_estudantes_ensino_fund_anos_finais               0.024563
# 35                 num_estudantes_fund_7_ano               0.024472
# 23                 num_estudantes_fund_1_ano               0.024220
# 11                            num_matriculas               0.023918
# 30                             num_equip_dvd               0.020966
# 20                              num_equip_tv               0.020081
# 27  num_estudantes_ensino_fund_anos_iniciais               0.018818
# 29                 num_estudantes_fund_3_ano               0.015616
# 6                  num_estudantes_fund_5_ano               0.015344
# 8                  num_estudantes_fund_6_ano               0.015072
# 40                 num_estudantes_fund_4_ano               0.014503
# 44          num_estudantes_medio_nao_seriada              -0.000317
# 41                  num_escolas_em_atividade              -0.004632
# 31              num_estudantes_medio_4_serie              -0.005368
# 45                               num_escolas              -0.008284

# %%
df_corr_fin_2017.sort_values(by=['correlation_with_ideb'], ascending=False)
# Out:
#                                      feature  correlation_with_ideb
# 33                                      ideb               1.000000
# 39                            num_comp_aluno               0.057646
# 2                             num_computador               0.055212
# 24                   num_comp_administrativo               0.053037
# 16                      num_equip_multimidia               0.051178
# 34                             num_equip_som               0.051044
# 22                      num_equip_impressora               0.046795
# 38                 num_equip_impressora_mult               0.046350
# 20                              num_equip_tv               0.046307
# 30                             num_equip_dvd               0.044513
# 19                   num_equip_retroprojetor               0.044168
# 3                     num_equip_videocassete               0.043131
# 10                             num_equip_fax               0.040613
# 18                            num_equip_foto               0.039969
# 32                       num_equip_copiadora               0.039064
# 12                 num_estudantes_fund_9_ano               0.038909
# 1                       num_salas_existentes               0.034432
# 5                            num_professores               0.034208
# 4               num_estudantes_medio_3_serie               0.033843
# 21                      num_equip_parabolica               0.033701
# 14            num_estudantes_ensino_infantil               0.033380
# 43                      num_salas_utilizadas               0.033052
# 42              num_estudantes_medio_2_serie               0.032662
# 25  num_estudantes_ensino_medio_propedeutico               0.032411
# 9                           num_funcionarios               0.032330
# 26                 num_estudantes_fund_8_ano               0.031252
# 15              num_estudantes_medio_1_serie               0.029532
# 23                 num_estudantes_fund_1_ano               0.027553
# 13                                num_turmas               0.027365
# 36                            num_estudantes               0.027275
# 28                 num_estudantes_fund_2_ano               0.027237
# 11                            num_matriculas               0.027037
# 37    num_estudantes_ensino_fund_anos_finais               0.026730
# 27  num_estudantes_ensino_fund_anos_iniciais               0.023087
# 35                 num_estudantes_fund_7_ano               0.022925
# 40                 num_estudantes_fund_4_ano               0.020820
# 6                  num_estudantes_fund_5_ano               0.020189
# 29                 num_estudantes_fund_3_ano               0.019838
# 8                  num_estudantes_fund_6_ano               0.016979
# 44          num_estudantes_medio_nao_seriada               0.009685
# 31              num_estudantes_medio_4_serie               0.008310
# 41                  num_escolas_em_atividade              -0.002991
# 45                               num_escolas              -0.010671

# %% [markdown]
# ## Separa anos iniciais de anos finais

# %%
df_result_ini_2015.filter(like='medio').columns
# Out:
# Index(['num_estudantes_ensino_medio_propedeutico',
#        'num_estudantes_medio_1_serie', 'num_estudantes_medio_2_serie',
#        'num_estudantes_medio_3_serie', 'num_estudantes_medio_4_serie',
#        'num_estudantes_medio_nao_seriada'],
#       dtype='object')

# %%
df_result_ini_2015 = df_result_ini_2015.drop(df_result_ini_2015.filter(like='medio').columns, axis=1)
df_result_ini_2017 = df_result_ini_2017.drop(df_result_ini_2017.filter(like='medio').columns, axis=1)

# %%
df_result_fin_2015.filter(like='fund').columns
# Out:
# Index(['num_estudantes_ensino_fund_anos_iniciais',
#        'num_estudantes_ensino_fund_anos_finais', 'num_estudantes_fund_1_ano',
#        'num_estudantes_fund_2_ano', 'num_estudantes_fund_3_ano',
#        'num_estudantes_fund_4_ano', 'num_estudantes_fund_5_ano',
#        'num_estudantes_fund_6_ano', 'num_estudantes_fund_7_ano',
#        'num_estudantes_fund_8_ano', 'num_estudantes_fund_9_ano'],
#       dtype='object')

# %%
df_result_fin_2015 = df_result_fin_2015.drop(df_result_fin_2015.filter(like='fund').columns, axis=1)
df_result_fin_2017 = df_result_fin_2017.drop(df_result_fin_2017.filter(like='fund').columns, axis=1)

df_result_fin_2015 = df_result_fin_2015.drop(['num_estudantes_ensino_infantil'], axis=1)
df_result_fin_2017 = df_result_fin_2017.drop(['num_estudantes_ensino_infantil'], axis=1)

# %%
print(df_result_ini_2015.shape)
print(df_result_ini_2017.shape)
print(df_result_fin_2015.shape)
print(df_result_fin_2017.shape)
# Out:
# (12048, 46)
# (12508, 46)
# (12158, 40)
# (12751, 40)

# %% [markdown]
# ## Salvar

# %%
df_result_ini_2015.to_csv('../../data/bases_ale/ideb_municipios_2015_ai.csv')
df_result_ini_2017.to_csv('../../data/bases_ale/ideb_municipios_2017_ai.csv')
df_result_fin_2015.to_csv('../../data/bases_ale/ideb_municipios_2015_af.csv')
df_result_fin_2017.to_csv('../../data/bases_ale/ideb_municipios_2017_af.csv')
